# %%
# Método para resolver las energías y eigenfunciones de un sistema cuántico numéricamente por Teoría de Pertubaciones
# Modelado Molecular 2
# By: José Manuel Casillas Martín     22-oct-2017
import numpy as np
from sympy import *
from sympy.physics.qho_1d import E_n, psi_n
from sympy.physics.hydrogen import E_nl, R_nl
from sympy import init_printing; init_printing(use_latex = 'mathjax')
from scipy import integrate
from scipy.constants import hbar, m_e, m_p, e
from mpmath import spherharm
from numpy import inf, array
import numpy as np
import matplotlib.pyplot as plt 
import traitlets
from IPython.display import display
from ipywidgets import Layout, Box, Text, Dropdown, Label, IntRangeSlider, IntSlider, RadioButtons

# %% [markdown]
# <h1><center>Teoría de Perturbaciones</center></h1>

# %% [markdown]
# Consiste en resolver un sistema perturbado(se conoce la solución al no perturbado), y donde el interés es conocer la contribución de la parte perturbada $H'$ al nuevo sistema total.

# %% [markdown]
# $$ H = H^{0}+H'$$

# %% [markdown]
# La resolución adecuada del problema, depende en gran parte, de una correcta elección de $H'$.

# %%
form_item_layout = Layout(display='flex',flex_flow='row',justify_content='space-between')

PType=Dropdown(options=['Particle in a one-dimensional box', 'Harmonic oscilator', 'Hydrogen atom (Helium correction)'])
Pert=Text()
Rang=IntRangeSlider(min=0, max=20, step=1, disabled=False, continuous_update=False, orientation='horizontal',\
                    readout=True, readout_format='d')
M=Text()
Correc=Dropdown(options=['1', '2'])
hbarra=Dropdown(options=[1, 1.0545718e-34])

form_items = [
    Box([Label(value='Problem'),PType], layout=form_item_layout),
    Box([Label(value='Perturbation'),Pert], layout=form_item_layout),
    Box([Label(value='Correction order'),Correc], layout=form_item_layout),
    Box([Label(value='n Range'),Rang], layout=form_item_layout),
    Box([Label(value='Mass'),M], layout=form_item_layout),
    Box([Label(value='Hbar'),hbarra], layout=form_item_layout),]

form = Box(form_items, layout=Layout(display='flex',flex_flow='column',border='solid 2px',align_items='stretch',width='40%'))
form

# %% [markdown]
# En esta caja interactiva llena los datos del problema que deseas resolver.

# %% [markdown]
# # Nota 1:
# Es recomendable usar unidades atómicas de Hartree para eficientar los cálculos. 1 u.a. (energía)= 27.211eV.

# %% [markdown]
# # Nota 2:
# Para la partícula en una caja unidimensional es recomendable que n sea mayor a 1.

# %% [markdown]
# ## Nota 3:
# Para la correción a la energía del átomo de Helio sólo es necesario seleccionar el problema, automáticamente se calcula la correción a primer orden y no se corrigen las funciones de onda.

# %%
Problem=PType.value
form_item_layout = Layout(display='flex',flex_flow='row',justify_content='space-between')

L=Text()
W=Text()
atomic_number=RadioButtons(options=['1 (Show Hydrogen energies)','2 (Correct Helium first energy)'],disabled=False)

if Problem=='Particle in a one-dimensional box':
    form_items = [Box([Label(value='Large of box'),L], layout=form_item_layout)]

if Problem=='Harmonic oscilator':
    form_items = [Box([Label(value='Angular Fr'),W], layout=form_item_layout)]

if Problem=='Hydrogen atom (Helium correction)':
    form_items = [Box([Label(value='Atomic number'),atomic_number], layout=form_item_layout)]

form = Box(form_items, layout=Layout(display='flex',flex_flow='column',border='solid 2px',align_items='stretch',width='40%'))
form

# %%
# Variables que se utilizarán
# x=variable de integracion, l=largo del pozo, m=masa del electrón, w=frecuencia angular
# n=número cuántico principal, Z=Número atómico, q=número cuántico angular(l)
var('x theta phi')
var('r1 r2', real=True)
var('l m hbar w n Z', positive=True, real=True)

# Perturbación
if Pert.value!='':
    H_p=sympify(Pert.value)
    h_p=eval(Pert.value)
else:
    H_p=0
    h_p=0

# Constantes
h=hbarra.value
a0=5.2917721067e-11
if M.value!='':
    mass=float(eval(M.value))
else:
    mass=1

# Energías y funciones que se desea corregir
n_inf=min(Rang.value)
n_sup=max(Rang.value)
    
if Problem=='Particle in a one-dimensional box':
    if L.value=='':
        large=1
    else:
        large=float(eval(L.value))
    omega=0
    # Energías del pozo de potencial infinito
    k=n*pi/l
    En=hbar**2*k**2/(2*m)
        
    # Funciones de onda del pozo de potencial infinito
    Psin=sqrt(2/l)*sin(n*pi*x/l)
    
    # Límites del pozo definido de 0 a l para sympy
    li_sympy=0
    ls_sympy=l
    # Mismo limites para scipy
    li_scipy=0
    ls_scipy=large

if Problem=='Harmonic oscilator':
    large=0
    if W.value=='':
        omega=1
    else:
        omega=float(eval(W.value))
    # Energías del oscilador armónico cuántico
    En=E_n(n,w)
    
    # Funciones de onda del oscilador armónico cuántico
    Psin=psi_n(n,x,m,w)

     # Límites del pozo definido de -oo a oo para sympy
    li_sympy=-oo
    ls_sympy=oo
    # Límites del pozo definido de -oo a oo para scipy
    li_scipy=-inf
    ls_scipy=inf
        
if Problem=='Hydrogen atom (Helium correction)':
    if atomic_number.value=='1 (Show Hydrogen energies)':
        z=1
    if atomic_number.value=='2 (Correct Helium first energy)':
        z=2
    large=0
    omega=0
    
    # Energías del átomo hidrogenoide
    En=z*E_nl(n,z)
    
    # Funciones de onda del átomo de hidrógeno
    # Número cuántico l=0
    q=0 # La variable l ya esta siendo utilizada para el largo de la caja por ello se sustituyo por q
    Psin=(R_nl(n,q,r1,z)*R_nl(n,q,r2,z))
    
     # Límites del átomo de hidrógeno de 0 a oo para sympy
    li_sympy=0
    ls_sympy=oo
    # Límites del átomo de hidrógeno de 0 a oo para scipy
    li_scipy=0
    ls_scipy=inf

# %% [markdown]
# Para sistemas no degenerados, la corrección a la energía a primer orden se calcula como
#
# $$ E_{n}^{(1)} = \int\psi_{n}^{(0)*} H' \psi_{n}^{(0)}d\tau$$

# %% [markdown]
# ** Tarea 1 : Programar esta ecuación si conoces $H^{0}$ y sus soluciones. **

# %%
def correcion_1st_order_Energy(E_n,Psi_n,H_p,li,ls):
    E1_n=Integral(Psi_n*(H_p)*Psi_n,(x,li,ls)).doit()
    return(E_n+E1_n)

# %%
# Correción de la energía a primer orden
E=[]
Eev=[]
Ec1=[]
if Problem=='Particle in a one-dimensional box' or Problem=='Harmonic oscilator':
    for i in range(n_inf,n_sup+1):
        E.append(En.subs({n:i}))
        Eev.append(E[i-n_inf].subs({m:mass, l:large, hbar:h}).evalf())
        Ec1.append(correcion_1st_order_Energy(En.subs({n:i}),Psin.subs({n:i}),H_p,li_sympy,ls_sympy))
if Problem=='Hydrogen atom (Helium correction)':
    for i in range(n_inf,n_sup+1):
        E.append(En.subs({n:i}))
        Eev.append(E[i-n_inf])
    if z==2:
        integral_1=Integral(Integral((16*z**6*r1*r2**2*exp(-2*z*(r1+r2))),(r2,0,r1)),(r1,0,oo)).doit()
        integral_2=Integral(Integral((16*z**6*r1**2*r2*exp(-2*z*(r1+r2))),(r2,r1,oo)),(r1,0,oo)).doit()
        integral_total=(integral_1+integral_2)
        Ec1.append(E[0]+integral_total)

# %% [markdown]
# Y la corrección a la función de onda, también a primer orden, se obtiene como:
#
#  $$ \psi_{n}^{(1)} = \sum_{m\neq n} \frac{\langle\psi_{m}^{(0)} | H' | \psi_{n}^{(0)} \rangle}{E_{n}^{(0)} - E_{m}^{(0)}} \psi_{m}^{(0)}$$

# %% [markdown]
# **Tarea 2: Programar esta ecuación si conoces $H^{0}$ y sus soluciones. **

# %%
# Correción de las funciones a primer orden
if Pert.value!='':
    if Problem=='Particle in a one-dimensional box' or Problem=='Harmonic oscilator':
        Psi_c=[]
        integrals=np.zeros((n_sup+1,n_sup+1))
        for i in range(n_inf,n_sup+1):
            a=0
            for j in range(n_inf,n_sup+1):
                if i!=j:
                    integ= lambda x: eval(str(Psin.subs({n:j})*(h_p)*Psin.subs({n:i}))).subs({m:mass,l:large,w:omega,hbar:h})
                    integrals[i,j]=integrate.quad(integ,li_scipy,ls_scipy)[0]
                    cte=integrals[i,j]/(En.subs({n:i,m:mass,l:large})-En.subs({n:j,m:mass,l:large})).evalf()
                    a=a+cte*Psin.subs({n:j})
            Psi_c.append(Psin.subs({n:i})+a)

# %% [markdown]
# **Tarea 3: Investigue las soluciones a segundo orden y también programe las soluciones. **

# %% [markdown]
# Y la corrección a la energía a segundo orden, se obtiene como:
#
#  $$  E_{n}^{(2)} = \sum_{m\neq n} \frac{|\langle\psi_{m}^{(0)} | H' | \psi_{n}^{(0)} \rangle|^{2}}{E_{n}^{(0)} - E_{m}^{(0)}} $$

# %%
# Correción a la energía a segundo orden
if Pert.value!='':
    if Problem=='Particle in a one-dimensional box' or Problem=='Harmonic oscilator':
        if Correc.value=='2':
            Ec2=[]
            for i in range(n_inf,n_sup+1):
                a=0
                for j in range(n_inf,n_sup+1):
                    if i!=j:
                        cte=((integrals[i,j])**2)/(En.subs({n:i,m:mass,l:large,hbar:h})-En.subs({n:j,m:mass,l:large,hbar:h})).evalf()
                        a=a+cte
                Ec2.append(Ec1[i-n_inf]+a)

# %% [markdown]
# **A continuación se muestran algunos de los resultados al problema resuelto**

# %% [markdown]
# Las energías sin perturbación son:

# %%
E
# Out:
# ⎡ℏ⋅w  3⋅ℏ⋅w  5⋅ℏ⋅w  7⋅ℏ⋅w⎤
# ⎢───, ─────, ─────, ─────⎥
# ⎣ 2     2      2      2  ⎦

# %% [markdown]
# La correción a primer orden de las energías son:

# %%
Ec1
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢                                     -m⋅w                           -m⋅w
# ⎢                                     ─────                          ─────
# ⎢                                       ℏ                              ℏ
# ⎢           ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ                 ⎛√m⋅√w⎞   √ℏ⋅ℯ
# ⎢      - √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────   - √π⋅erfc⎜─────⎟ + ─────────
# ⎢ℏ⋅w        ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w              ⎝  √ℏ ⎠     √m⋅√w
# ⎢─── + ──────────────────────────────────── + ──────────────────────────── + 2
# ⎢ 2                    2⋅√π                               2⋅√π
# ⎣
#
#
#
#      ⎛   ⎛                                   -m⋅w ⎞
#      ⎜   ⎜                                   ─────⎟              m⋅w
#      ⎜   ⎜                                     ℏ  ⎟              ───
#      ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ
#      ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ
#      ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π
#    ℏ⋅⎜────────────────────────────────────────────────────────────── - ───────
#      ⎝                              2                                  2⋅√m⋅√w
#  + ───────────────────────────────────────────────────────────────────────────
#                                          2⋅π⋅m⋅w
#
#
#
#
# ⎞            ⎛   ⎛                           -m⋅w ⎞
# ⎟            ⎜   ⎜                           ─────⎟              m⋅w
# ⎟            ⎜   ⎜                             ℏ  ⎟              ───
# ⎟  -m⋅w      ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ
# ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ
# ⎟    ℏ       ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π
# ⎟⋅ℯ        ℏ⋅⎜────────────────────────────────────────────────────── + ───────
# ⎠            ⎝                          2                              2⋅√m⋅√w
# ──────── + ───────────────────────────────────────────────────────────────────
#                                              2⋅π⋅m⋅w
#
#
#
#
# ⎞
# ⎟
# ⎟               ⎛                               -m⋅w ⎞         ⎛
# ⎟  -m⋅w         ⎜                               ─────⎟         ⎜
# ⎟  ─────        ⎜                                 ℏ  ⎟         ⎜
# ⎟    ℏ          ⎜     ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ     ⎟         ⎜         ⎛√m⋅√
# ⎟⋅ℯ       5⋅m⋅w⋅⎜- √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────⎟   5⋅m⋅w⋅⎜- √π⋅erfc⎜────
# ⎠               ⎝     ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w  ⎠         ⎝         ⎝  √ℏ
# ────────, ──────────────────────────────────────────── + ─────────────────────
#                               ℏ⋅√π                                       ℏ⋅√π
#
#
#
#
#                                                                             ⎛
#                                                                             ⎜
#          -m⋅w ⎞                                                             ⎜
#          ─────⎟                                                             ⎜
#            ℏ  ⎟                                                             ⎜√
# w⎞   √ℏ⋅ℯ     ⎟         ⎛      ⎛√m⋅√w⎞    ⎞             ⎛√m⋅√w⎞             ⎜
# ─⎟ + ─────────⎟   2⋅m⋅w⋅⎜- erfc⎜─────⎟ + 2⎟   2⋅m⋅w⋅erfc⎜─────⎟           5⋅⎜─
#  ⎠     √m⋅√w  ⎠         ⎝      ⎝  √ℏ ⎠    ⎠             ⎝  √ℏ ⎠   3⋅ℏ⋅w     ⎝
# ─────────────── + ───────────────────────── + ───────────────── + ───── + ────
#                               ℏ                       ℏ             2
#
#
#
#
#   ⎛                                   -m⋅w ⎞                           ⎞
#   ⎜                                   ─────⎟              m⋅w          ⎟
#   ⎜                                     ℏ  ⎟              ───          ⎟
#   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w
# π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ────
#   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ
# ───────────────────────────────────────────────────────────── - ───────⎟⋅ℯ
#                              2                                  2⋅√m⋅√w⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                      π
#
#
#
#
#       ⎛   ⎛                           -m⋅w ⎞                           ⎞
#       ⎜   ⎜                           ─────⎟              m⋅w          ⎟
#       ⎜   ⎜                             ℏ  ⎟              ───          ⎟
#       ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w
# ─     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ────
#       ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ
#     5⋅⎜────────────────────────────────────────────────────── + ───────⎟⋅ℯ
#       ⎝                          2                              2⋅√m⋅√w⎠
# ─ + ──────────────────────────────────────────────────────────────────────────
#                                          π
#
#
#       ⎛     ⎛                                 -m⋅w            -m⋅w ⎞
#       ⎜     ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟
#       ⎜     ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2
#       ⎜     ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w
#       ⎜3⋅√π⋅⎜──────────────────────── + ─────────── - ─────────────⎟⋅⎜───── +
#       ⎜     ⎜           3                 3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2
# ─     ⎜     ⎝                                          3⋅m   ⋅w    ⎠ ⎝  ℏ
#     ℏ⋅⎜───────────────────────────────────────────────────────────────────────
#       ⎜                                          4
#       ⎝
# ─ + ──────────────────────────────────────────────────────────────────────────
#                                                               π⋅m⋅w
#
#
#                                        ⎞            ⎛     ⎛
#             m⋅w                        ⎟            ⎜     ⎜         ⎛√m⋅√w⎞
#          ⎞  ───                        ⎟            ⎜     ⎜4⋅√π⋅erfc⎜─────⎟
# 3⋅m⋅w   3⎟   ℏ                         ⎟            ⎜     ⎜         ⎝  √ℏ ⎠
# ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w      ⎜3⋅√π⋅⎜──────────────── -
#   ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────     ⎜     ⎜       3
#          ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ       ⎜     ⎝
# ─────────────── - ─────────────────────⎟⋅ℯ        ℏ⋅⎜─────────────────────────
#                          3/2  3/2      ⎟            ⎜
#                         m   ⋅w         ⎠            ⎝
# ─────────────────────────────────────────────── + ────────────────────────────
#
#
#
#       -m⋅w            -m⋅w ⎞                                                 ⎞
#       ─────           ─────⎟                      m⋅w                        ⎟
#         ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───                        ⎟
# 4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ                         ⎟
# ─────────── + ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟
#   3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟
#                3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠                ⎝   4⋅ℏ    8⎠⎟
# ───────────────────────────────────────────────────── + ─────────────────────⎟
#              4                                                 3/2  3/2      ⎟
#                                                               m   ⋅w         ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                           π⋅m⋅w
#
#
#
#                ⎛                         ⎛                                 -m⋅
#                ⎜                         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ───
#                ⎜                         ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ
#   -m⋅w         ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ
#   ─────        ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ─────────
#     ℏ          ⎜             ⎝   ℏ    2⎠ ⎜           3                 3⋅√m⋅√w
# ⋅ℯ             ⎜                         ⎝
#           3⋅√ℏ⋅⎜- ────────────────────────────────────────────────────────────
#                ⎝                                          4⋅√ℏ
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                              π⋅√m⋅√w
#
#
#
# w            -m⋅w ⎞              ⎞               ⎛                       ⎛
# ──           ─────⎟  m⋅w         ⎟               ⎜                       ⎜
#         3/2    ℏ  ⎟  ───         ⎟               ⎜                       ⎜4⋅√π
#      2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜           ⎛  m⋅w   3⎞ ⎜
# ── - ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜────
#          3/2  3/2 ⎟              ⎟  ─────        ⎜           ⎝   ℏ    2⎠ ⎜
#       3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ          ⎜                       ⎝
# ──────────────────────── + ──────⎟⋅ℯ        3⋅√ℏ⋅⎜────────────────────────────
#                            4⋅m⋅w ⎠               ⎝
# ───────────────────────────────────────── + ──────────────────────────────────
#
#
#
#
#                      -m⋅w            -m⋅w ⎞              ⎞
#      ⎛√m⋅√w⎞         ─────           ─────⎟  m⋅w         ⎟
# ⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟
#      ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟
# ──────────── - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w
#    3             3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────
#                               3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ
# ──────────────────────────────────────────────── + ──────⎟⋅ℯ         18⋅√m⋅√w⋅
#         4⋅√ℏ                                       4⋅m⋅w ⎠
# ─────────────────────────────────────────────────────────────────, - ─────────
#             π⋅√m⋅√w
#
#
#
# ⎛                         ⎛                                 -m⋅w            -m
# ⎜                         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ──
# ⎜                         ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2
# ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ
# ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ─────────── - ──────────
# ⎜             ⎝   ℏ    2⎠ ⎜           3                 3⋅√m⋅√w         3/2  3
# ⎜                         ⎝                                          3⋅m   ⋅w
# ⎜- ───────────────────────────────────────────────────────────────────────────
# ⎝                                          4⋅√ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                               √ℏ⋅π
#
#
#
# ⋅w ⎞              ⎞                   ⎛                       ⎛
# ───⎟  m⋅w         ⎟                   ⎜                       ⎜         ⎛√m⋅√w
# ℏ  ⎟  ───         ⎟                   ⎜                       ⎜4⋅√π⋅erfc⎜─────
#    ⎟   ℏ          ⎟                   ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ
# ───⎟⋅ℯ            ⎟  -m⋅w             ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜───────────────
# /2 ⎟              ⎟  ─────            ⎜           ⎝   ℏ    2⎠ ⎜       3
#    ⎠        3⋅ℏ⋅√π⎟    ℏ              ⎜                       ⎝
# ───────── + ──────⎟⋅ℯ        18⋅√m⋅√w⋅⎜───────────────────────────────────────
#             4⋅m⋅w ⎠                   ⎝                                    4⋅√
# ────────────────────────── + ─────────────────────────────────────────────────
#
#
#
#
#           -m⋅w            -m⋅w ⎞              ⎞
# ⎞         ─────           ─────⎟  m⋅w         ⎟
# ⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟
# ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟                  ⎛
# ─ - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w            ⎜
#       3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────           ⎜
#                    3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ        2  2 ⎜     ⎛
# ───────────────────────────────────── + ──────⎟⋅ℯ        9⋅m ⋅w ⋅⎜- √π⋅⎜- erfc
# ℏ                                       4⋅m⋅w ⎠                  ⎝     ⎝
# ────────────────────────────────────────────────────── + ─────────────────────
#  √ℏ⋅π
#                                                                              ℏ
#
#
#
#
#
#                    -m⋅w ⎞           ⎛                       -m⋅w ⎞
#                    ─────⎟           ⎜                       ─────⎟
#                      ℏ  ⎟           ⎜                         ℏ  ⎟
# ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ     ⎟      2  2 ⎜         ⎛√m⋅√w⎞   √ℏ⋅ℯ     ⎟      2  2 ⎛
# ⎜─────⎟ + 2⎟ - ─────────⎟   9⋅m ⋅w ⋅⎜- √π⋅erfc⎜─────⎟ + ─────────⎟   2⋅m ⋅w ⋅⎜
# ⎝  √ℏ ⎠    ⎠     √m⋅√w  ⎠           ⎝         ⎝  √ℏ ⎠     √m⋅√w  ⎠           ⎝
# ───────────────────────── + ────────────────────────────────────── + ─────────
# 2                                            2
#  ⋅√π                                        ℏ ⋅√π
#
#
#
#
#
#                                                  ⎛
#                                                  ⎜
#                                                  ⎜
#       ⎛√m⋅√w⎞    ⎞      2  2     ⎛√m⋅√w⎞         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞   √
# - erfc⎜─────⎟ + 2⎟   2⋅m ⋅w ⋅erfc⎜─────⎟   5⋅m⋅w⋅⎜- √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─
#       ⎝  √ℏ ⎠    ⎠               ⎝  √ℏ ⎠         ⎝     ⎝      ⎝  √ℏ ⎠    ⎠
# ────────────────── + ─────────────────── - ───────────────────────────────────
#      2                         2                               ℏ⋅√π
#     ℏ                         ℏ
#
#
#
#                                                           ⎛   ⎛
#                                                           ⎜   ⎜
#    -m⋅w ⎞         ⎛                       -m⋅w ⎞          ⎜   ⎜
#    ─────⎟         ⎜                       ─────⎟          ⎜   ⎜       ⎛      ⎛
#      ℏ  ⎟         ⎜                         ℏ  ⎟          ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜
# ℏ⋅ℯ     ⎟         ⎜         ⎛√m⋅√w⎞   √ℏ⋅ℯ     ⎟          ⎜   ⎝       ⎝      ⎝
# ────────⎟   5⋅m⋅w⋅⎜- √π⋅erfc⎜─────⎟ + ─────────⎟   17⋅m⋅w⋅⎜───────────────────
#  √m⋅√w  ⎠         ⎝         ⎝  √ℏ ⎠     √m⋅√w  ⎠          ⎝
# ───────── - ──────────────────────────────────── + ───────────────────────────
#                             ℏ⋅√π
#
#
#
#
#                     -m⋅w ⎞                           ⎞                 ⎛   ⎛
#                     ─────⎟              m⋅w          ⎟                 ⎜   ⎜
#                       ℏ  ⎟              ───          ⎟                 ⎜   ⎜
# √m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w           ⎜   ⎜
# ─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────          ⎜√π⋅⎜-
#   √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ            ⎜   ⎝
# ─────────────────────────────────────────── - ───────⎟⋅ℯ        17⋅m⋅w⋅⎜──────
#            2                                  2⋅√m⋅√w⎠                 ⎝
# ───────────────────────────────────────────────────────────── + ──────────────
#                ℏ⋅π
#
#
#
#
#                          -m⋅w ⎞                           ⎞
#                          ─────⎟              m⋅w          ⎟
#                            ℏ  ⎟              ───          ⎟
#          ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w
# 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────
#          ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ           ⎛
# ──────────────────────────────────────────────── + ───────⎟⋅ℯ        2⋅m⋅w⋅⎜-
#                     2                              2⋅√m⋅√w⎠                ⎝
# ────────────────────────────────────────────────────────────────── - ─────────
#                         ℏ⋅π
#
#
#
#
#
#
#
#
#
#     ⎛√m⋅√w⎞    ⎞             ⎛√m⋅√w⎞                ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ
# erfc⎜─────⎟ + 2⎟   2⋅m⋅w⋅erfc⎜─────⎟           - √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ────
#     ⎝  √ℏ ⎠    ⎠             ⎝  √ℏ ⎠   5⋅ℏ⋅w        ⎝      ⎝  √ℏ ⎠    ⎠     √m
# ──────────────── - ───────────────── + ───── + ───────────────────────────────
#    ℏ                       ℏ             2                     4⋅√π
#
#
#
#
#                                          ⎛   ⎛
#                                          ⎜   ⎜
# -m⋅w                           -m⋅w      ⎜   ⎜
# ─────                          ─────     ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√
#   ℏ                              ℏ       ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───
#                  ⎛√m⋅√w⎞   √ℏ⋅ℯ          ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠
# ─────   - √π⋅erfc⎜─────⎟ + ─────────   5⋅⎜────────────────────────────────────
# ⋅√w              ⎝  √ℏ ⎠     √m⋅√w       ⎝                              2
# ───── + ──────────────────────────── - ───────────────────────────────────────
#                     4⋅√π
#
#
#
#
#    -m⋅w ⎞                           ⎞            ⎛   ⎛
#    ─────⎟              m⋅w          ⎟            ⎜   ⎜
#      ℏ  ⎟              ───          ⎟            ⎜   ⎜
# ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√
# ────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───
# √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ       ⎜   ⎝           ⎝  √ℏ ⎠
# ────────────────────────── - ───────⎟⋅ℯ        5⋅⎜────────────────────────────
#                              2⋅√m⋅√w⎠            ⎝                          2
# ──────────────────────────────────────────── - ───────────────────────────────
#   π
#
#
#                                                   ⎛     ⎛
#                                                   ⎜     ⎜     ⎛      ⎛√m⋅√w⎞
#    -m⋅w ⎞                           ⎞             ⎜     ⎜4⋅√π⋅⎜- erfc⎜─────⎟ +
#    ─────⎟              m⋅w          ⎟             ⎜     ⎜     ⎝      ⎝  √ℏ ⎠
#      ℏ  ⎟              ───          ⎟             ⎜3⋅√π⋅⎜─────────────────────
# ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w       ⎜     ⎜           3
# ────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────      ⎜     ⎝
# √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ     12⋅⎜───────────────────────────
# ────────────────────────── + ───────⎟⋅ℯ           ⎜
#                              2⋅√m⋅√w⎠             ⎝
# ──────────────────────────────────────────── + ───────────────────────────────
#       π
#
#
#             -m⋅w            -m⋅w ⎞
#   ⎞         ─────           ─────⎟                      m⋅w
#  2⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───
#   ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ
# ─── + ─────────── - ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w
#         3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ─────
#                      3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠                ⎝   4⋅ℏ
# ─────────────────────────────────────────────────────────── - ────────────────
#                4                                                     3/2  3/2
#                                                                     m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                              π
#
#
#      ⎞             ⎛     ⎛                         -m⋅w            -m⋅w ⎞
#      ⎟             ⎜     ⎜         ⎛√m⋅√w⎞         ─────           ─────⎟
#      ⎟             ⎜     ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2
#      ⎟             ⎜     ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅
#    3⎞⎟  -m⋅w       ⎜3⋅√π⋅⎜──────────────── - ─────────── + ─────────────⎟⋅⎜───
#  - ─⎟⎟  ─────      ⎜     ⎜       3             3⋅√m⋅√w         3/2  3/2 ⎟ ⎜
#    8⎠⎟    ℏ        ⎜     ⎝                                  3⋅m   ⋅w    ⎠ ⎝  ℏ
# ─────⎟⋅ℯ        12⋅⎜──────────────────────────────────────────────────────────
#      ⎟             ⎜                                      4
#      ⎠             ⎝
# ───────────── + ──────────────────────────────────────────────────────────────
#                                                                         π
#
#
#                                             ⎞
#                  m⋅w                        ⎟
#  2            ⎞  ───                        ⎟                ⎛   ⎛
# w    3⋅m⋅w   3⎟   ℏ                         ⎟                ⎜   ⎜
# ── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w          ⎜   ⎜
# 2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────         ⎜   ⎜       ⎛
#               ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ           ⎜√π⋅⎜- 2⋅√π⋅⎜- er
# ──────────────────── + ─────────────────────⎟⋅ℯ              ⎜   ⎝       ⎝
#                               3/2  3/2      ⎟              ℏ⋅⎜────────────────
#                              m   ⋅w         ⎠                ⎝
# ──────────────────────────────────────────────────── + 1 + ───────────────────
#
#
#
#
#
#                        -m⋅w ⎞                           ⎞            ⎛   ⎛
#                        ─────⎟              m⋅w          ⎟            ⎜   ⎜
#                          ℏ  ⎟              ───          ⎟            ⎜   ⎜
#   ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜   ⎜
# fc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜√π⋅⎜- 2⋅
#   ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ       ⎜   ⎝
# ────────────────────────────────────────────── - ───────⎟⋅ℯ        ℏ⋅⎜────────
#               2                                  2⋅√m⋅√w⎠            ⎝
# ──────────────────────────────────────────────────────────────── + ───────────
#                    4⋅π⋅m⋅w
#
#
#                                                                      ⎛     ⎛
#                                                                      ⎜     ⎜
#                        -m⋅w ⎞                           ⎞            ⎜     ⎜4⋅
#                        ─────⎟              m⋅w          ⎟            ⎜     ⎜
#                          ℏ  ⎟              ───          ⎟            ⎜3⋅√π⋅⎜──
#        ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜     ⎜
# √π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜     ⎝
#        ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ     ℏ⋅⎜────────
# ────────────────────────────────────────────── + ───────⎟⋅ℯ          ⎜
#                   2                              2⋅√m⋅√w⎠            ⎝
# ──────────────────────────────────────────────────────────────── - ───────────
#                        4⋅π⋅m⋅w
#
#
#                                -m⋅w            -m⋅w ⎞
#    ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟                      m⋅w
# √π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───
#    ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ
# ────────────────────── + ─────────── - ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ
#          3                 3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟
#                                         3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                   4
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                π⋅m⋅w
#
#
#                         ⎞            ⎛     ⎛                         -m⋅w
#                         ⎟            ⎜     ⎜         ⎛√m⋅√w⎞         ─────
#                         ⎟            ⎜     ⎜4⋅√π⋅erfc⎜─────⎟           ℏ
#                         ⎟            ⎜     ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2
#     3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w      ⎜3⋅√π⋅⎜──────────────── - ─────────── + ─
#    ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────     ⎜     ⎜       3             3⋅√m⋅√w
#            ⎝   4⋅ℏ    8⎠⎟    ℏ       ⎜     ⎝
#  - ─────────────────────⎟⋅ℯ        ℏ⋅⎜────────────────────────────────────────
#           3/2  3/2      ⎟            ⎜                                      4
#          m   ⋅w         ⎠            ⎝
# ──────────────────────────────── - ───────────────────────────────────────────
#
#
#
#        -m⋅w ⎞                                                 ⎞            ⎛
#        ─────⎟                      m⋅w                        ⎟            ⎜
#   3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───                        ⎟            ⎜
# ⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ                         ⎟            ⎜
# ────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w      ⎜15
#    3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────     ⎜
# 3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ       ⎜
# ────────────────────────────────────── + ─────────────────────⎟⋅ℯ        ℏ⋅⎜──
#                                                 3/2  3/2      ⎟            ⎜
#                                                m   ⋅w         ⎠            ⎝
# ────────────────────────────────────────────────────────────────────── + ─────
#            π⋅m⋅w
#
#
#     ⎛                                   -m⋅w            -m⋅w            -m⋅w ⎞
#     ⎜       ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────           ─────⎟
#     ⎜  8⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ        5/2    ℏ  ⎟
#     ⎜       ⎝      ⎝  √ℏ ⎠    ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟
# ⋅√π⋅⎜- ──────────────────────── - ─────────── + ───────────── - ─────────────⎟
#     ⎜             15                15⋅√m⋅√w         3/2  3/2       5/2  5/2 ⎟
#     ⎝                                            15⋅m   ⋅w       5⋅m   ⋅w    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                          8
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            π⋅m
#
#
#                                                                            ⎞
#                                      m⋅w                                   ⎟
#  ⎛   3  3       2  2              ⎞  ───           ⎛    2  2              ⎞⎟
#  ⎜  m ⋅w    15⋅m ⋅w    45⋅m⋅w   15⎟   ℏ     5/2    ⎜15⋅m ⋅w    15⋅m⋅w   45⎟⎟
# ⋅⎜- ───── - ──────── - ────── - ──⎟⋅ℯ      ℏ   ⋅√π⋅⎜──────── + ────── + ──⎟⎟
#  ⎜     3         2      4⋅ℏ     8 ⎟                ⎜     2      2⋅ℏ     32⎟⎟
#  ⎝    ℏ       2⋅ℏ                 ⎠                ⎝  8⋅ℏ                 ⎠⎟
# ──────────────────────────────────────── - ────────────────────────────────⎟⋅ℯ
#                                                        5/2  5/2            ⎟
#                                                       m   ⋅w               ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ⋅w
#
#
#           ⎛      ⎛                           -m⋅w            -m⋅w            -
#           ⎜      ⎜           ⎛√m⋅√w⎞         ─────           ─────           ─
#           ⎜      ⎜  8⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ        5/2
#           ⎜      ⎜           ⎝  √ℏ ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ
# -m⋅w      ⎜15⋅√π⋅⎜- ──────────────── + ─────────── - ───────────── + ─────────
# ─────     ⎜      ⎜         15            15⋅√m⋅√w         3/2  3/2       5/2
#   ℏ       ⎜      ⎝                                    15⋅m   ⋅w       5⋅m   ⋅w
#         ℏ⋅⎜───────────────────────────────────────────────────────────────────
#           ⎜                                                       8
#           ⎝
# ───── + ──────────────────────────────────────────────────────────────────────
#
#
#
# m⋅w ⎞
# ────⎟                                     m⋅w
#  ℏ  ⎟ ⎛   3  3       2  2              ⎞  ───           ⎛    2  2
#     ⎟ ⎜  m ⋅w    15⋅m ⋅w    45⋅m⋅w   15⎟   ℏ     5/2    ⎜15⋅m ⋅w    15⋅m⋅w   4
# ────⎟⋅⎜- ───── - ──────── - ────── - ──⎟⋅ℯ      ℏ   ⋅√π⋅⎜──────── + ────── + ─
# 5/2 ⎟ ⎜     3         2      4⋅ℏ     8 ⎟                ⎜     2      2⋅ℏ     3
#     ⎠ ⎝    ℏ       2⋅ℏ                 ⎠                ⎝  8⋅ℏ
# ───────────────────────────────────────────── + ──────────────────────────────
#                                                             5/2  5/2
#                                                            m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#       π⋅m⋅w
#
#
#   ⎞
#   ⎟               ⎛                         ⎛
#  ⎞⎟               ⎜                         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞
# 5⎟⎟               ⎜                         ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟
# ─⎟⎟  -m⋅w         ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ
# 2⎟⎟  ─────        ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ──────
#  ⎠⎟    ℏ          ⎜             ⎝   ℏ    2⎠ ⎜           3                 3⋅√m
# ──⎟⋅ℯ             ⎜                         ⎝
#   ⎟          3⋅√ℏ⋅⎜- ─────────────────────────────────────────────────────────
#   ⎠               ⎝                                          4⋅√ℏ
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                                 π⋅√m⋅√w
#
#
#
# -m⋅w            -m⋅w ⎞              ⎞               ⎛                       ⎛
# ─────           ─────⎟  m⋅w         ⎟               ⎜                       ⎜
#   ℏ        3/2    ℏ  ⎟  ───         ⎟               ⎜                       ⎜4
#         2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜           ⎛  m⋅w   3⎞ ⎜
# ───── - ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜─
# ⋅√w         3/2  3/2 ⎟              ⎟  ─────        ⎜           ⎝   ℏ    2⎠ ⎜
#          3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ          ⎜                       ⎝
# ─────────────────────────── + ──────⎟⋅ℯ        3⋅√ℏ⋅⎜─────────────────────────
#                               4⋅m⋅w ⎠               ⎝
# ──────────────────────────────────────────── - ───────────────────────────────
#
#
#
#                                                                             ⎛
#                         -m⋅w            -m⋅w ⎞              ⎞               ⎜
#         ⎛√m⋅√w⎞         ─────           ─────⎟  m⋅w         ⎟               ⎜
# ⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟               ⎜
#         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜
# ─────────────── - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜
#       3             3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────        ⎜
#                                  3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ     5⋅√ℏ⋅⎜-
# ─────────────────────────────────────────────────── + ──────⎟⋅ℯ             ⎜
#            4⋅√ℏ                                       4⋅m⋅w ⎠               ⎝
# ──────────────────────────────────────────────────────────────────── - ───────
#                π⋅√m⋅√w
#
#
#                                   ⎛                                   -m⋅w
#                                   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞         ─────
#              ⎛ 2  2             ⎞ ⎜  8⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ
#              ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜       ⎝      ⎝  √ℏ ⎠    ⎠   8⋅√ℏ⋅ℯ
#  15⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────────────── - ─────────── +
#              ⎜   2      ℏ     4 ⎟ ⎜             15                15⋅√m⋅√w
#              ⎝  ℏ               ⎠ ⎝
#  ─────────────────────────────────────────────────────────────────────────────
#                                                        8⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  π⋅√m⋅√w
#
#
#         -m⋅w            -m⋅w ⎞                             ⎞               ⎛
#         ─────           ─────⎟  m⋅w                        ⎟               ⎜
#    3/2    ℏ        5/2    ℏ  ⎟  ───                        ⎟               ⎜
# 4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟               ⎜
# ───────────── - ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w         ⎜15
#      3/2  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────        ⎜
#  15⋅m   ⋅w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ          ⎜
# ─────────────────────────────────── + ─────────────────────⎟⋅ℯ        5⋅√ℏ⋅⎜──
#                                                2  2        ⎟               ⎜
#                                               m ⋅w         ⎠               ⎝
# ─────────────────────────────────────────────────────────────────── + ────────
#
#
#
#                                ⎛                           -m⋅w            -m⋅
#                                ⎜           ⎛√m⋅√w⎞         ─────           ───
#           ⎛ 2  2             ⎞ ⎜  8⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ
#           ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜           ⎝  √ℏ ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ
# ⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────── + ─────────── - ───────────
#           ⎜   2      ℏ     4 ⎟ ⎜         15            15⋅√m⋅√w         3/2  3
#           ⎝  ℏ               ⎠ ⎝                                    15⋅m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                                                 8⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                            π⋅√m⋅√w
#
#
# w            -m⋅w ⎞                             ⎞
# ──           ─────⎟  m⋅w                        ⎟                         ⎛
#         5/2    ℏ  ⎟  ───                        ⎟                         ⎜
#      2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟                         ⎜
# ── + ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w                   ⎜
# /2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────                  ⎜  3
#       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ                    ⎜
# ──────────────────────── + ─────────────────────⎟⋅ℯ              3/2  3/2 ⎜
#                                     2  2        ⎟           122⋅m   ⋅w   ⋅⎜- ─
#                                    m ⋅w         ⎠                         ⎝
# ────────────────────────────────────────────────────────, - ──────────────────
#
#
#
#
#                       ⎛                                 -m⋅w            -m⋅w ⎞
#                       ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟
#                       ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟
#           ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟
# ⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ─────────── - ─────────────⎟
#           ⎝   ℏ    2⎠ ⎜           3                 3⋅√m⋅√w         3/2  3/2 ⎟
#                       ⎝                                          3⋅m   ⋅w    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                        4⋅√ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                         3/2
#                                      3⋅ℏ   ⋅π
#
#
#               ⎞                        ⎛                       ⎛
#   m⋅w         ⎟                        ⎜                       ⎜         ⎛√m⋅√
#   ───         ⎟                        ⎜                       ⎜4⋅√π⋅erfc⎜────
#    ℏ          ⎟                        ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ
# ⋅ℯ            ⎟  -m⋅w                  ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────
#               ⎟  ─────                 ⎜           ⎝   ℏ    2⎠ ⎜       3
#         3⋅ℏ⋅√π⎟    ℏ          3/2  3/2 ⎜                       ⎝
# ───── + ──────⎟⋅ℯ        122⋅m   ⋅w   ⋅⎜──────────────────────────────────────
#         4⋅m⋅w ⎠                        ⎝                                    4⋅
# ────────────────────── + ─────────────────────────────────────────────────────
#
#                                                                            3⋅ℏ
#
#
#            -m⋅w            -m⋅w ⎞              ⎞                   ⎛
# w⎞         ─────           ─────⎟  m⋅w         ⎟                   ⎜
# ─⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟                   ⎜
#  ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟                   ⎜
# ── - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w             ⎜  3⋅√π⋅√m⋅
#        3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────            ⎜
#                     3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ              ⎜
# ────────────────────────────────────── + ──────⎟⋅ℯ        36⋅√m⋅√w⋅⎜- ────────
# ...
#  ⎟ ⎜   4        3            2       2⋅ℏ      16⎟                ⎜        3
#  ⎠ ⎝  ℏ        ℏ          2⋅ℏ                   ⎠                ⎝    16⋅ℏ
# ────────────────────────────────────────────────────── - ─────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      3⋅π⋅m⋅w
#
#
#                                ⎞              ⎛       ⎛
#                                ⎟              ⎜       ⎜          ⎛√m⋅√w⎞
#         2  2                  ⎞⎟              ⎜       ⎜16⋅√π⋅erfc⎜─────⎟
#   1995⋅m ⋅w    5985⋅m⋅w   1575⎟⎟              ⎜       ⎜          ⎝  √ℏ ⎠   16⋅
# - ────────── - ──────── - ────⎟⎟  -m⋅w        ⎜105⋅√π⋅⎜───────────────── - ───
#         2        64⋅ℏ     128 ⎟⎟  ─────       ⎜       ⎜       105           10
#     32⋅ℏ                      ⎠⎟    ℏ         ⎜       ⎝
# ───────────────────────────────⎟⋅ℯ        2⋅ℏ⋅⎜───────────────────────────────
#  7/2  7/2                      ⎟              ⎜
# m   ⋅w                         ⎠              ⎝
# ─────────────────────────────────────── + ────────────────────────────────────
#
#
#
#     -m⋅w            -m⋅w            -m⋅w            -m⋅w ⎞
#     ─────           ─────           ─────           ─────⎟
#       ℏ        3/2    ℏ        5/2    ℏ        7/2    ℏ  ⎟ ⎛ 4  4       3  3
# √ℏ⋅ℯ        8⋅ℏ   ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    14⋅m ⋅w
# ───────── + ───────────── - ───────────── + ─────────────⎟⋅⎜───── + ──────── +
# 5⋅√m⋅√w          3/2  3/2        5/2  5/2       7/2  7/2 ⎟ ⎜   4        3
#             105⋅m   ⋅w       35⋅m   ⋅w       7⋅m   ⋅w    ⎠ ⎝  ℏ        ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                        16
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  3⋅π⋅m⋅w
#
#
#
#                              m⋅w
#       2  2                ⎞  ───           ⎛       3  3         2  2
#  105⋅m ⋅w    105⋅m⋅w   105⎟   ℏ     7/2    ⎜  105⋅m ⋅w    1995⋅m ⋅w    5985⋅m⋅
#  ───────── + ─────── + ───⎟⋅ℯ      ℏ   ⋅√π⋅⎜- ───────── - ────────── - ───────
#        2       2⋅ℏ      16⎟                ⎜        3           2        64⋅ℏ
#     2⋅ℏ                   ⎠                ⎝    16⋅ℏ        32⋅ℏ
# ──────────────────────────────── + ───────────────────────────────────────────
#                                                          7/2  7/2
#                                                         m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ⎞
#          ⎟               ⎛                         ⎛
#         ⎞⎟               ⎜                         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞
# w   1575⎟⎟               ⎜                         ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟
# ─ - ────⎟⎟  -m⋅w         ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠
#     128 ⎟⎟  ─────        ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── +
#         ⎠⎟    ℏ          ⎜             ⎝   ℏ    2⎠ ⎜           3
# ─────────⎟⋅ℯ             ⎜                         ⎝
#          ⎟          9⋅√ℏ⋅⎜- ──────────────────────────────────────────────────
#          ⎠               ⎝                                          4⋅√ℏ
# ───────────────── - ──────────────────────────────────────────────────────────
#                                                                       2⋅π⋅√m⋅√
#
#
#
#        -m⋅w            -m⋅w ⎞              ⎞               ⎛
#        ─────           ─────⎟  m⋅w         ⎟               ⎜
#          ℏ        3/2    ℏ  ⎟  ───         ⎟               ⎜
#  4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜           ⎛  m⋅w
#  ─────────── - ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜3⋅√π⋅√m⋅√w⋅⎜- ───
#    3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────        ⎜           ⎝   ℏ
#                 3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ          ⎜
# ────────────────────────────────── + ──────⎟⋅ℯ        9⋅√ℏ⋅⎜──────────────────
#                                      4⋅m⋅w ⎠               ⎝
# ─────────────────────────────────────────────────── + ────────────────────────
# w
#
#
#
#      ⎛                         -m⋅w            -m⋅w ⎞              ⎞
#      ⎜         ⎛√m⋅√w⎞         ─────           ─────⎟  m⋅w         ⎟
#      ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟
#   3⎞ ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟
# - ─⎟⋅⎜──────────────── - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w
#   2⎠ ⎜       3             3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────
#      ⎝                                  3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ
# ────────────────────────────────────────────────────────── + ──────⎟⋅ℯ
#                   4⋅√ℏ                                       4⋅m⋅w ⎠
# ─────────────────────────────────────────────────────────────────────────── +
#                      2⋅π⋅√m⋅√w
#
#
#       ⎛                                   ⎛
#       ⎜                                   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞
#       ⎜              ⎛ 2  2             ⎞ ⎜  8⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟
#       ⎜              ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜       ⎝      ⎝  √ℏ ⎠    ⎠   8⋅√ℏ⋅ℯ
#       ⎜  15⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────────────── - ──────
#       ⎜              ⎜   2      ℏ     4 ⎟ ⎜             15                15⋅√
#       ⎜              ⎝  ℏ               ⎠ ⎝
# 10⋅√ℏ⋅⎜- ─────────────────────────────────────────────────────────────────────
#       ⎜                                                        8⋅√ℏ
#       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          π⋅√m⋅
#
#
# -m⋅w            -m⋅w            -m⋅w ⎞                             ⎞
# ─────           ─────           ─────⎟  m⋅w                        ⎟
#   ℏ        3/2    ℏ        5/2    ℏ  ⎟  ───                        ⎟
#         4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟
# ───── + ───────────── - ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w
# m⋅√w         3/2  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────
#          15⋅m   ⋅w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ
# ─────────────────────────────────────────── + ─────────────────────⎟⋅ℯ
#                                                        2  2        ⎟
#                                                       m ⋅w         ⎠
# ─────────────────────────────────────────────────────────────────────────── -
# √w
#
#
#       ⎛                                 ⎛                           -m⋅w
#       ⎜                                 ⎜           ⎛√m⋅√w⎞         ─────
#       ⎜            ⎛ 2  2             ⎞ ⎜  8⋅√π⋅erfc⎜─────⎟           ℏ
#       ⎜            ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜           ⎝  √ℏ ⎠   8⋅√ℏ⋅ℯ        4⋅
#       ⎜15⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────── + ─────────── - ──
#       ⎜            ⎜   2      ℏ     4 ⎟ ⎜         15            15⋅√m⋅√w
#       ⎜            ⎝  ℏ               ⎠ ⎝                                    1
# 10⋅√ℏ⋅⎜───────────────────────────────────────────────────────────────────────
#       ⎜                                                  8⋅√ℏ
#       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     π⋅√m⋅√w
#
#
#       -m⋅w            -m⋅w ⎞                             ⎞                ⎛
#       ─────           ─────⎟  m⋅w                        ⎟                ⎜
#  3/2    ℏ        5/2    ℏ  ⎟  ───                        ⎟                ⎜
# ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟                ⎜
# ─────────── + ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w          ⎜  1
#    3/2  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────         ⎜
# 5⋅m   ⋅w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ           ⎜
# ───────────────────────────────── + ─────────────────────⎟⋅ℯ        14⋅√ℏ⋅⎜- ─
#                                              2  2        ⎟                ⎜
#                                             m ⋅w         ⎠                ⎝
# ───────────────────────────────────────────────────────────────── - ──────────
#
#
#
#                                                  ⎛
#                                                  ⎜      ⎛      ⎛√m⋅√w⎞    ⎞
#             ⎛   3  3       2  2                ⎞ ⎜16⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟
#             ⎜  m ⋅w    21⋅m ⋅w    105⋅m⋅w   105⎟ ⎜      ⎝      ⎝  √ℏ ⎠    ⎠
# 05⋅√π⋅√m⋅√w⋅⎜- ───── - ──────── - ─────── - ───⎟⋅⎜───────────────────────── +
#             ⎜     3         2       4⋅ℏ      8 ⎟ ⎜           105
#             ⎝    ℏ       2⋅ℏ                   ⎠ ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      16⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        -m⋅w            -m⋅w            -m⋅w            -m⋅w ⎞
#        ─────           ─────           ─────           ─────⎟  m⋅w
#          ℏ        3/2    ℏ        5/2    ℏ        7/2    ℏ  ⎟  ───         ⎛
# 16⋅√ℏ⋅ℯ        8⋅ℏ   ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ     3    ⎜10
# ──────────── - ───────────── + ───────────── - ─────────────⎟⋅ℯ      ℏ ⋅√π⋅⎜──
#  105⋅√m⋅√w          3/2  3/2        5/2  5/2       7/2  7/2 ⎟              ⎜
#                105⋅m   ⋅w       35⋅m   ⋅w       7⋅m   ⋅w    ⎠              ⎝
# ────────────────────────────────────────────────────────────────── + ─────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        3⋅π⋅√m⋅√w
#
#
#                          ⎞                ⎛
#                          ⎟                ⎜
#    2  2                 ⎞⎟                ⎜             ⎛   3  3       2  2
# 5⋅m ⋅w    315⋅m⋅w   1575⎟⎟                ⎜             ⎜  m ⋅w    21⋅m ⋅w
# ─────── + ─────── + ────⎟⎟  -m⋅w          ⎜105⋅√π⋅√m⋅√w⋅⎜- ───── - ──────── -
#     2       8⋅ℏ      64 ⎟⎟  ─────         ⎜             ⎜     3         2
# 16⋅ℏ                    ⎠⎟    ℏ           ⎜             ⎝    ℏ       2⋅ℏ
# ─────────────────────────⎟⋅ℯ        14⋅√ℏ⋅⎜───────────────────────────────────
#       3  3               ⎟                ⎜
#      m ⋅w                ⎠                ⎝
# ───────────────────────────────── + ──────────────────────────────────────────
#
#
#
#                ⎛                           -m⋅w            -m⋅w            -m⋅
#                ⎜          ⎛√m⋅√w⎞          ─────           ─────           ───
#              ⎞ ⎜16⋅√π⋅erfc⎜─────⎟            ℏ        3/2    ℏ        5/2    ℏ
# 105⋅m⋅w   105⎟ ⎜          ⎝  √ℏ ⎠   16⋅√ℏ⋅ℯ        8⋅ℏ   ⋅ℯ        4⋅ℏ   ⋅ℯ
# ─────── - ───⎟⋅⎜───────────────── - ──────────── + ───────────── - ───────────
#   4⋅ℏ      8 ⎟ ⎜       105           105⋅√m⋅√w          3/2  3/2        5/2  5
#              ⎠ ⎝                                   105⋅m   ⋅w       35⋅m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                                16⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3⋅π⋅√m⋅√w
#
#
# w            -m⋅w ⎞                                          ⎞       ⎤
# ──           ─────⎟  m⋅w                                     ⎟       ⎥
#         7/2    ℏ  ⎟  ───         ⎛     2  2                 ⎞⎟       ⎥
#      2⋅ℏ   ⋅ℯ     ⎟   ℏ     3    ⎜105⋅m ⋅w    315⋅m⋅w   1575⎟⎟       ⎥
# ── + ─────────────⎟⋅ℯ      ℏ ⋅√π⋅⎜───────── + ─────── + ────⎟⎟  -m⋅w ⎥
# /2       7/2  7/2 ⎟              ⎜      2       8⋅ℏ      64 ⎟⎟  ─────⎥
#       7⋅m   ⋅w    ⎠              ⎝  16⋅ℏ                    ⎠⎟    ℏ  ⎥
# ──────────────────────── + ──────────────────────────────────⎟⋅ℯ     ⎥
#                                           3  3               ⎟       ⎥
#                                          m ⋅w                ⎠       ⎥
# ─────────────────────────────────────────────────────────────────────⎥
#                                                                      ⎥
#                                                                      ⎦

# %% [markdown]
# Si seleccionaste en los parámetros iniciales una correción a segundo orden entonces...

# %% [markdown]
# Las correciones a la energía a segundo orden son:

# %%
Ec2
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢                                     -m⋅w                           -m⋅w
# ⎢                                     ─────                          ─────
# ⎢                                       ℏ                              ℏ
# ⎢           ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ                 ⎛√m⋅√w⎞   √ℏ⋅ℯ
# ⎢      - √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────   - √π⋅erfc⎜─────⎟ + ─────────
# ⎢ℏ⋅w        ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w              ⎝  √ℏ ⎠     √m⋅√w
# ⎢─── + ──────────────────────────────────── + ──────────────────────────── + 2
# ⎢ 2                    2⋅√π                               2⋅√π
# ⎣
#
#
#
#                             ⎛   ⎛                                   -m⋅w ⎞
#                             ⎜   ⎜                                   ─────⎟
#                             ⎜   ⎜                                     ℏ  ⎟
#                             ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛
#                             ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜-
#                             ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝
#                           ℏ⋅⎜─────────────────────────────────────────────────
#    7.11189250474996e+33     ⎝                              2
#  - ──────────────────── + ────────────────────────────────────────────────────
#             w                                                   2⋅π⋅m⋅w
#
#
#
#
#                        ⎞            ⎛   ⎛                           -m⋅w ⎞
#           m⋅w          ⎟            ⎜   ⎜                           ─────⎟
#           ───          ⎟            ⎜   ⎜                             ℏ  ⎟
# m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛
# ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜-
#  ℏ    2⎠         √ℏ⋅√π ⎟    ℏ       ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝
# ───────────── - ───────⎟⋅ℯ        ℏ⋅⎜─────────────────────────────────────────
#                 2⋅√m⋅√w⎠            ⎝                          2
# ─────────────────────────────── + ────────────────────────────────────────────
#                                                                     2⋅π⋅m⋅w
#
#
#
#
#                        ⎞
#           m⋅w          ⎟
#           ───          ⎟               ⎛                               -m⋅w ⎞
# m⋅w   1⎞   ℏ           ⎟  -m⋅w         ⎜                               ─────⎟
# ─── - ─⎟⋅ℯ             ⎟  ─────        ⎜                                 ℏ  ⎟
#  ℏ    2⎠         √ℏ⋅√π ⎟    ℏ          ⎜     ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ     ⎟
# ───────────── + ───────⎟⋅ℯ       5⋅m⋅w⋅⎜- √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────⎟
#                 2⋅√m⋅√w⎠               ⎝     ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w  ⎠
# ───────────────────────────────, ────────────────────────────────────────────
#                                                      ℏ⋅√π
#
#
#
#
#
#
#         ⎛                       -m⋅w ⎞
#         ⎜                       ─────⎟
#         ⎜                         ℏ  ⎟
#         ⎜         ⎛√m⋅√w⎞   √ℏ⋅ℯ     ⎟         ⎛      ⎛√m⋅√w⎞    ⎞
#   5⋅m⋅w⋅⎜- √π⋅erfc⎜─────⎟ + ─────────⎟   2⋅m⋅w⋅⎜- erfc⎜─────⎟ + 2⎟   2⋅m⋅w⋅erf
#         ⎝         ⎝  √ℏ ⎠     √m⋅√w  ⎠         ⎝      ⎝  √ℏ ⎠    ⎠
# + ──────────────────────────────────── + ───────────────────────── + ─────────
#                   ℏ⋅√π                               ℏ                       ℏ
#
#
#
#
#                      ⎛   ⎛                                   -m⋅w ⎞
#                      ⎜   ⎜                                   ─────⎟
#                      ⎜   ⎜                                     ℏ  ⎟
#                      ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1
#                      ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─
#  ⎛√m⋅√w⎞             ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2
# c⎜─────⎟           5⋅⎜────────────────────────────────────────────────────────
#  ⎝  √ℏ ⎠   3⋅ℏ⋅w     ⎝                              2
# ──────── + ───── + ───────────────────────────────────────────────────────────
#              2                                              π
#
#
#
#
#                 ⎞            ⎛   ⎛                           -m⋅w ⎞
#    m⋅w          ⎟            ⎜   ⎜                           ─────⎟
#    ───          ⎟            ⎜   ⎜                             ℏ  ⎟
# ⎞   ℏ           ⎟  -m⋅w      ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1
# ⎟⋅ℯ             ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─
# ⎠         √ℏ⋅√π ⎟    ℏ       ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2
# ────── - ───────⎟⋅ℯ        5⋅⎜────────────────────────────────────────────────
#          2⋅√m⋅√w⎠            ⎝                          2
# ──────────────────────── + ───────────────────────────────────────────────────
#                                                                 π
#
#
#                                                     ⎛     ⎛
#                                                     ⎜     ⎜     ⎛      ⎛√m⋅√w⎞
#                 ⎞                                   ⎜     ⎜4⋅√π⋅⎜- erfc⎜─────⎟
#    m⋅w          ⎟                                   ⎜     ⎜     ⎝      ⎝  √ℏ ⎠
#    ───          ⎟                                   ⎜3⋅√π⋅⎜───────────────────
# ⎞   ℏ           ⎟  -m⋅w                             ⎜     ⎜           3
# ⎟⋅ℯ             ⎟  ─────                            ⎜     ⎝
# ⎠         √ℏ⋅√π ⎟    ℏ                            ℏ⋅⎜─────────────────────────
# ────── + ───────⎟⋅ℯ                                 ⎜
#          2⋅√m⋅√w⎠          1.18531541745832e+34     ⎝
# ──────────────────────── - ──────────────────── + ────────────────────────────
#                                     w
#
#
#               -m⋅w            -m⋅w ⎞
#     ⎞         ─────           ─────⎟                      m⋅w
#  + 2⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───
#     ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ
# ───── + ─────────── - ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m
#           3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───
#                        3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠                ⎝   4⋅
# ───────────────────────────────────────────────────────────── - ──────────────
#                  4                                                     3/2  3/
#                                                                       m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                               π⋅m⋅w
#
#
#        ⎞            ⎛     ⎛                         -m⋅w            -m⋅w ⎞
#        ⎟            ⎜     ⎜         ⎛√m⋅√w⎞         ─────           ─────⎟
#        ⎟            ⎜     ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2
#        ⎟            ⎜     ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m
# ⋅w   3⎞⎟  -m⋅w      ⎜3⋅√π⋅⎜──────────────── - ─────────── + ─────────────⎟⋅⎜──
# ── - ─⎟⎟  ─────     ⎜     ⎜       3             3⋅√m⋅√w         3/2  3/2 ⎟ ⎜
# ℏ    8⎠⎟    ℏ       ⎜     ⎝                                  3⋅m   ⋅w    ⎠ ⎝
# ───────⎟⋅ℯ        ℏ⋅⎜─────────────────────────────────────────────────────────
# 2      ⎟            ⎜                                      4
#        ⎠            ⎝
# ─────────────── + ────────────────────────────────────────────────────────────
#                                                                         π⋅m⋅w
#
#
#                                              ⎞
#                   m⋅w                        ⎟               ⎛
#   2            ⎞  ───                        ⎟               ⎜
# ⋅w    3⋅m⋅w   3⎟   ℏ                         ⎟               ⎜
# ─── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w         ⎜             ⎛
#  2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────        ⎜  3⋅√π⋅√m⋅√w⋅⎜-
# ℏ              ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ          ⎜             ⎝
# ───────────────────── + ─────────────────────⎟⋅ℯ             ⎜
#                                3/2  3/2      ⎟          3⋅√ℏ⋅⎜- ──────────────
#                               m   ⋅w         ⎠               ⎝
# ───────────────────────────────────────────────────── - ──────────────────────
#
#
#
#
#          ⎛                                 -m⋅w            -m⋅w ⎞
#          ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟  m⋅w
#          ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟  ───
# m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ
# ─── - ─⎟⋅⎜──────────────────────── + ─────────── - ─────────────⎟⋅ℯ
#  ℏ    2⎠ ⎜           3                 3⋅√m⋅√w         3/2  3/2 ⎟
#          ⎝                                          3⋅m   ⋅w    ⎠        3⋅ℏ⋅√
# ────────────────────────────────────────────────────────────────────── + ─────
#                           4⋅√ℏ                                           4⋅m⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                              π⋅√m⋅√w
#
#
#
#  ⎞               ⎛                       ⎛                         -m⋅w
#  ⎟               ⎜                       ⎜         ⎛√m⋅√w⎞         ─────
#  ⎟               ⎜                       ⎜4⋅√π⋅erfc⎜─────⎟           ℏ
#  ⎟               ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ
#  ⎟  -m⋅w         ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────── - ─────────── + ───
#  ⎟  ─────        ⎜           ⎝   ℏ    2⎠ ⎜       3             3⋅√m⋅√w
# π⎟    ℏ          ⎜                       ⎝                                  3⋅
# ─⎟⋅ℯ        3⋅√ℏ⋅⎜────────────────────────────────────────────────────────────
#  ⎠               ⎝                                    4⋅√ℏ
# ───────── + ──────────────────────────────────────────────────────────────────
#                                                           π⋅√m⋅√w
#
#
#
#      -m⋅w ⎞              ⎞                    ⎛                         ⎛
#      ─────⎟  m⋅w         ⎟                    ⎜                         ⎜
# 3/2    ℏ  ⎟  ───         ⎟                    ⎜                         ⎜4⋅√π⋅
#    ⋅ℯ     ⎟   ℏ          ⎟                    ⎜             ⎛  m⋅w   3⎞ ⎜
# ──────────⎟⋅ℯ            ⎟  -m⋅w              ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜─────
#  3/2  3/2 ⎟              ⎟  ─────             ⎜             ⎝   ℏ    2⎠ ⎜
# m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ               ⎜                         ⎝
# ──────────────── + ──────⎟⋅ℯ         18⋅√m⋅√w⋅⎜- ─────────────────────────────
#                    4⋅m⋅w ⎠                    ⎝
# ─────────────────────────────────, - ─────────────────────────────────────────
#
#
#
#
#                             -m⋅w            -m⋅w ⎞              ⎞
# ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟  m⋅w         ⎟
# ⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟
# ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟
# ─────────────────── + ─────────── - ─────────────⎟⋅ℯ            ⎟  -m⋅w
#       3                 3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────
#                                      3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ
# ─────────────────────────────────────────────────────── + ──────⎟⋅ℯ        18⋅
#            4⋅√ℏ                                           4⋅m⋅w ⎠
# ──────────────────────────────────────────────────────────────────────── + ───
#               √ℏ⋅π
#
#
#
#       ⎛                       ⎛                         -m⋅w            -m⋅w ⎞
#       ⎜                       ⎜         ⎛√m⋅√w⎞         ─────           ─────⎟
#       ⎜                       ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟
#       ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟
#       ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────── - ─────────── + ─────────────⎟
#       ⎜           ⎝   ℏ    2⎠ ⎜       3             3⋅√m⋅√w         3/2  3/2 ⎟
#       ⎜                       ⎝                                  3⋅m   ⋅w    ⎠
# √m⋅√w⋅⎜───────────────────────────────────────────────────────────────────────
#       ⎝                                    4⋅√ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                                √ℏ⋅π
#
#
#
#               ⎞
#   m⋅w         ⎟
#   ───         ⎟
#    ℏ          ⎟                  ⎛                               -m⋅w ⎞
# ⋅ℯ            ⎟  -m⋅w            ⎜                               ─────⎟
#               ⎟  ─────           ⎜                                 ℏ  ⎟
#         3⋅ℏ⋅√π⎟    ℏ        2  2 ⎜     ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ     ⎟      2
# ───── + ──────⎟⋅ℯ        9⋅m ⋅w ⋅⎜- √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────⎟   9⋅m
#         4⋅m⋅w ⎠                  ⎝     ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w  ⎠
# ────────────────────── + ────────────────────────────────────────────── + ────
#                                               2
#                                              ℏ ⋅√π
#
#
#
#
#
#     ⎛                       -m⋅w ⎞
#     ⎜                       ─────⎟
#     ⎜                         ℏ  ⎟
#   2 ⎜         ⎛√m⋅√w⎞   √ℏ⋅ℯ     ⎟      2  2 ⎛      ⎛√m⋅√w⎞    ⎞      2  2
# ⋅w ⋅⎜- √π⋅erfc⎜─────⎟ + ─────────⎟   2⋅m ⋅w ⋅⎜- erfc⎜─────⎟ + 2⎟   2⋅m ⋅w ⋅erf
#     ⎝         ⎝  √ℏ ⎠     √m⋅√w  ⎠           ⎝      ⎝  √ℏ ⎠    ⎠
# ────────────────────────────────── + ─────────────────────────── + ───────────
#              2                                     2                         2
#             ℏ ⋅√π                                 ℏ                         ℏ
#
#
#
#
#
#                  ⎛                               -m⋅w ⎞         ⎛
#                  ⎜                               ─────⎟         ⎜
#                  ⎜                                 ℏ  ⎟         ⎜
#  ⎛√m⋅√w⎞         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ     ⎟         ⎜         ⎛√m⋅
# c⎜─────⎟   5⋅m⋅w⋅⎜- √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────⎟   5⋅m⋅w⋅⎜- √π⋅erfc⎜───
#  ⎝  √ℏ ⎠         ⎝     ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w  ⎠         ⎝         ⎝  √
# ──────── - ──────────────────────────────────────────── - ────────────────────
#                                ℏ⋅√π                                       ℏ⋅√π
#
#
#
#
#                           ⎛   ⎛                                   -m⋅w ⎞
#                           ⎜   ⎜                                   ─────⎟
#           -m⋅w ⎞          ⎜   ⎜                                     ℏ  ⎟
#           ─────⎟          ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅
#             ℏ  ⎟          ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ──
# √w⎞   √ℏ⋅ℯ     ⎟          ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ
# ──⎟ + ─────────⎟   17⋅m⋅w⋅⎜───────────────────────────────────────────────────
# ℏ ⎠     √m⋅√w  ⎠          ⎝                              2
# ──────────────── + ───────────────────────────────────────────────────────────
#                                                              ℏ⋅π
#
#
#
#
#                      ⎞                 ⎛   ⎛                           -m⋅w ⎞
#         m⋅w          ⎟                 ⎜   ⎜                           ─────⎟
#         ───          ⎟                 ⎜   ⎜                             ℏ  ⎟
# w   1⎞   ℏ           ⎟  -m⋅w           ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟
# ─ - ─⎟⋅ℯ             ⎟  ─────          ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅
#     2⎠         √ℏ⋅√π ⎟    ℏ            ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠
# ─────────── - ───────⎟⋅ℯ        17⋅m⋅w⋅⎜──────────────────────────────────────
#               2⋅√m⋅√w⎠                 ⎝                          2
# ───────────────────────────── + ──────────────────────────────────────────────
#                                                                       ℏ⋅π
#
#
#
#
#                           ⎞
#              m⋅w          ⎟
#              ───          ⎟
# ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w
# ⎜- ─── - ─⎟⋅ℯ             ⎟  ─────
# ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ           ⎛      ⎛√m⋅√w⎞    ⎞             ⎛√m
# ──────────────── + ───────⎟⋅ℯ        2⋅m⋅w⋅⎜- erfc⎜─────⎟ + 2⎟   2⋅m⋅w⋅erfc⎜──
#                    2⋅√m⋅√w⎠                ⎝      ⎝  √ℏ ⎠    ⎠             ⎝
# ────────────────────────────────── - ───────────────────────── - ─────────────
#                                                  ℏ                       ℏ
#
#
#
#
#
#
#                                               -m⋅w                           -
#                                               ─────                          ─
#                                                 ℏ
# ⋅√w⎞                ⎛      ⎛√m⋅√w⎞    ⎞   √ℏ⋅ℯ                 ⎛√m⋅√w⎞   √ℏ⋅ℯ
# ───⎟           - √π⋅⎜- erfc⎜─────⎟ + 2⎟ - ─────────   - √π⋅erfc⎜─────⎟ + ─────
# √ℏ ⎠   5⋅ℏ⋅w        ⎝      ⎝  √ℏ ⎠    ⎠     √m⋅√w              ⎝  √ℏ ⎠     √m⋅
# ──── + ───── + ──────────────────────────────────── + ────────────────────────
#          2                     4⋅√π                               4⋅√π
#
#
#
#
#          ⎛   ⎛                                   -m⋅w ⎞
#          ⎜   ⎜                                   ─────⎟              m⋅w
# m⋅w      ⎜   ⎜                                     ℏ  ⎟              ───
# ────     ⎜   ⎜       ⎛      ⎛√m⋅√w⎞    ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ
#  ℏ       ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ
#          ⎜   ⎝       ⎝      ⎝  √ℏ ⎠    ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ
# ────   5⋅⎜────────────────────────────────────────────────────────────── - ───
# √w       ⎝                              2                                  2⋅√
# ──── - ───────────────────────────────────────────────────────────────────────
#                                                 π
#
#
#
#
#     ⎞            ⎛   ⎛                           -m⋅w ⎞
#     ⎟            ⎜   ⎜                           ─────⎟              m⋅w
#     ⎟            ⎜   ⎜                             ℏ  ⎟              ───
#     ⎟  -m⋅w      ⎜   ⎜           ⎛√m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ
#     ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ
# ⋅√π ⎟    ℏ       ⎜   ⎝           ⎝  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ
# ────⎟⋅ℯ        5⋅⎜────────────────────────────────────────────────────── + ───
# m⋅√w⎠            ⎝                          2                              2⋅√
# ──────────── - ───────────────────────────────────────────────────────────────
#                                                     π
#
#
#                   ⎛     ⎛                                 -m⋅w            -m⋅w
#                   ⎜     ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ────
#     ⎞             ⎜     ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ
#     ⎟             ⎜     ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ
#     ⎟             ⎜3⋅√π⋅⎜──────────────────────── + ─────────── - ────────────
#     ⎟  -m⋅w       ⎜     ⎜           3                 3⋅√m⋅√w         3/2  3/2
#     ⎟  ─────      ⎜     ⎝                                          3⋅m   ⋅w
# ⋅√π ⎟    ℏ     12⋅⎜───────────────────────────────────────────────────────────
# ────⎟⋅ℯ           ⎜                                          4
# m⋅√w⎠             ⎝
# ──────────── + ───────────────────────────────────────────────────────────────
#                                                                            π
#
#
#  ⎞                                                 ⎞             ⎛     ⎛
# ─⎟                      m⋅w                        ⎟             ⎜     ⎜
#  ⎟ ⎛ 2  2            ⎞  ───                        ⎟             ⎜     ⎜4⋅√π⋅e
#  ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ                         ⎟             ⎜     ⎜
# ─⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w       ⎜3⋅√π⋅⎜──────
#  ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────      ⎜     ⎜
#  ⎠ ⎝  ℏ              ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ        ⎜     ⎝
# ─────────────────────────── - ─────────────────────⎟⋅ℯ        12⋅⎜────────────
#                                      3/2  3/2      ⎟             ⎜
#                                     m   ⋅w         ⎠             ⎝
# ─────────────────────────────────────────────────────────── + ────────────────
#
#
#
#                    -m⋅w            -m⋅w ⎞
#    ⎛√m⋅√w⎞         ─────           ─────⎟                      m⋅w
# rfc⎜─────⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───
#    ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ
# ────────── - ─────────── + ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛
#  3             3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜
#                             3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠                ⎝
# ────────────────────────────────────────────────────────────────── + ─────────
#                           4                                                 3/
#                                                                            m
# ──────────────────────────────────────────────────────────────────────────────
#                                         π
#
#
#             ⎞
#             ⎟
#             ⎟                                       ⎛   ⎛
#             ⎟                                       ⎜   ⎜
#   3⋅m⋅w   3⎞⎟  -m⋅w                                 ⎜   ⎜
# - ───── - ─⎟⎟  ─────                                ⎜   ⎜       ⎛      ⎛√m⋅√w⎞
#    4⋅ℏ    8⎠⎟    ℏ                                  ⎜√π⋅⎜- 2⋅√π⋅⎜- erfc⎜─────⎟
# ────────────⎟⋅ℯ                                     ⎜   ⎝       ⎝      ⎝  √ℏ ⎠
# 2  3/2      ⎟                                     ℏ⋅⎜─────────────────────────
#  ⋅w         ⎠              2.37063083491666e+33     ⎝
# ──────────────────── + 1 - ──────────────────── + ────────────────────────────
#                                     w
#
#
#
#
#               -m⋅w ⎞                           ⎞            ⎛   ⎛
#               ─────⎟              m⋅w          ⎟            ⎜   ⎜
#                 ℏ  ⎟              ───          ⎟            ⎜   ⎜
#     ⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜   ⎜           ⎛√
#  + 2⎟ - ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜√π⋅⎜- 2⋅√π⋅erfc⎜─
#     ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ       ⎜   ⎝           ⎝
# ───────────────────────────────────── - ───────⎟⋅ℯ        ℏ⋅⎜─────────────────
#      2                                  2⋅√m⋅√w⎠            ⎝
# ─────────────────────────────────────────────────────── + ────────────────────
#           4⋅π⋅m⋅w
#
#
#                                                             ⎛     ⎛
#                                                             ⎜     ⎜     ⎛
#               -m⋅w ⎞                           ⎞            ⎜     ⎜4⋅√π⋅⎜- erf
#               ─────⎟              m⋅w          ⎟            ⎜     ⎜     ⎝
#                 ℏ  ⎟              ───          ⎟            ⎜3⋅√π⋅⎜───────────
# m⋅√w⎞   2⋅√ℏ⋅ℯ     ⎟ ⎛  m⋅w   1⎞   ℏ           ⎟  -m⋅w      ⎜     ⎜
# ────⎟ + ───────────⎟⋅⎜- ─── - ─⎟⋅ℯ             ⎟  ─────     ⎜     ⎝
#  √ℏ ⎠      √m⋅√w   ⎠ ⎝   ℏ    2⎠         √ℏ⋅√π ⎟    ℏ     ℏ⋅⎜─────────────────
# ───────────────────────────────────── + ───────⎟⋅ℯ          ⎜
#          2                              2⋅√m⋅√w⎠            ⎝
# ─────────────────────────────────────────────────────── - ────────────────────
#               4⋅π⋅m⋅w
#
#
#                       -m⋅w            -m⋅w ⎞
#  ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟                      m⋅w
# c⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟ ⎛ 2  2            ⎞  ───
#  ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ
# ───────────── + ─────────── - ─────────────⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2
# 3                 3⋅√m⋅√w         3/2  3/2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√
#                                3⋅m   ⋅w    ⎠ ⎝  ℏ              ⎠
# ───────────────────────────────────────────────────────────────────── - ──────
#                          4
#
# ──────────────────────────────────────────────────────────────────────────────
#                                       π⋅m⋅w
#
#
#                ⎞            ⎛     ⎛                         -m⋅w            -m
#                ⎟            ⎜     ⎜         ⎛√m⋅√w⎞         ─────           ──
#                ⎟            ⎜     ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2
#                ⎟            ⎜     ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ
#   ⎛  3⋅m⋅w   3⎞⎟  -m⋅w      ⎜3⋅√π⋅⎜──────────────── - ─────────── + ──────────
# π⋅⎜- ───── - ─⎟⎟  ─────     ⎜     ⎜       3             3⋅√m⋅√w         3/2  3
#   ⎝   4⋅ℏ    8⎠⎟    ℏ       ⎜     ⎝                                  3⋅m   ⋅w
# ───────────────⎟⋅ℯ        ℏ⋅⎜─────────────────────────────────────────────────
#  3/2  3/2      ⎟            ⎜                                      4
# m   ⋅w         ⎠            ⎝
# ─────────────────────── - ────────────────────────────────────────────────────
#
#
#
# ⋅w ⎞                                                 ⎞            ⎛      ⎛
# ───⎟                      m⋅w                        ⎟            ⎜      ⎜
# ℏ  ⎟ ⎛ 2  2            ⎞  ───                        ⎟            ⎜      ⎜  8⋅
#    ⎟ ⎜m ⋅w    3⋅m⋅w   3⎟   ℏ                         ⎟            ⎜      ⎜
# ───⎟⋅⎜───── + ───── + ─⎟⋅ℯ       3/2    ⎛  3⋅m⋅w   3⎞⎟  -m⋅w      ⎜15⋅√π⋅⎜- ──
# /2 ⎟ ⎜   2      ℏ     4⎟        ℏ   ⋅√π⋅⎜- ───── - ─⎟⎟  ─────     ⎜      ⎜
#    ⎠ ⎝  ℏ              ⎠                ⎝   4⋅ℏ    8⎠⎟    ℏ       ⎜      ⎝
# ───────────────────────────── + ─────────────────────⎟⋅ℯ        ℏ⋅⎜───────────
#                                        3/2  3/2      ⎟            ⎜
#                                       m   ⋅w         ⎠            ⎝
# ───────────────────────────────────────────────────────────── + ──────────────
#   π⋅m⋅w
#
#
#                                -m⋅w            -m⋅w            -m⋅w ⎞
#    ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────           ─────⎟
# √π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ        5/2    ℏ  ⎟ ⎛   3  3
#    ⎝      ⎝  √ℏ ⎠    ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜  m ⋅w
# ────────────────────── - ─────────── + ───────────── - ─────────────⎟⋅⎜- ─────
#          15                15⋅√m⋅√w         3/2  3/2       5/2  5/2 ⎟ ⎜     3
#                                         15⋅m   ⋅w       5⋅m   ⋅w    ⎠ ⎝    ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                                 8
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   π⋅m⋅w
#
#
#                                                                   ⎞
#                             m⋅w                                   ⎟
#        2  2              ⎞  ───           ⎛    2  2              ⎞⎟
#    15⋅m ⋅w    45⋅m⋅w   15⎟   ℏ     5/2    ⎜15⋅m ⋅w    15⋅m⋅w   45⎟⎟
#  - ──────── - ────── - ──⎟⋅ℯ      ℏ   ⋅√π⋅⎜──────── + ────── + ──⎟⎟  -m⋅w
#         2      4⋅ℏ     8 ⎟                ⎜     2      2⋅ℏ     32⎟⎟  ─────
#      2⋅ℏ                 ⎠                ⎝  8⋅ℏ                 ⎠⎟    ℏ
# ─────────────────────────────── - ────────────────────────────────⎟⋅ℯ        ℏ
#                                               5/2  5/2            ⎟
#                                              m   ⋅w               ⎠
# ────────────────────────────────────────────────────────────────────────── + ─
#
#
#
#  ⎛      ⎛                           -m⋅w            -m⋅w            -m⋅w ⎞
#  ⎜      ⎜           ⎛√m⋅√w⎞         ─────           ─────           ─────⎟
#  ⎜      ⎜  8⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ        5/2    ℏ  ⎟ ⎛
#  ⎜      ⎜           ⎝  √ℏ ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜
#  ⎜15⋅√π⋅⎜- ──────────────── + ─────────── - ───────────── + ─────────────⎟⋅⎜-
#  ⎜      ⎜         15            15⋅√m⋅√w         3/2  3/2       5/2  5/2 ⎟ ⎜
#  ⎜      ⎝                                    15⋅m   ⋅w       5⋅m   ⋅w    ⎠ ⎝
# ⋅⎜────────────────────────────────────────────────────────────────────────────
#  ⎜                                                       8
#  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            π⋅m
#
#
#                                                                        ⎞
#                                  m⋅w                                   ⎟
#  3  3       2  2              ⎞  ───           ⎛    2  2              ⎞⎟
# m ⋅w    15⋅m ⋅w    45⋅m⋅w   15⎟   ℏ     5/2    ⎜15⋅m ⋅w    15⋅m⋅w   45⎟⎟
# ───── - ──────── - ────── - ──⎟⋅ℯ      ℏ   ⋅√π⋅⎜──────── + ────── + ──⎟⎟  -m⋅w
#    3         2      4⋅ℏ     8 ⎟                ⎜     2      2⋅ℏ     32⎟⎟  ────
#   ℏ       2⋅ℏ                 ⎠                ⎝  8⋅ℏ                 ⎠⎟    ℏ
# ──────────────────────────────────── + ────────────────────────────────⎟⋅ℯ
#                                                    5/2  5/2            ⎟
#                                                   m   ⋅w               ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ⋅w
#
#
#
#          ⎛                         ⎛                                 -m⋅w
#          ⎜                         ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────
#          ⎜                         ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ
#          ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2
# ─        ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ─────────── - ─
#          ⎜             ⎝   ℏ    2⎠ ⎜           3                 3⋅√m⋅√w
#          ⎜                         ⎝
#     3⋅√ℏ⋅⎜- ──────────────────────────────────────────────────────────────────
#          ⎝                                          4⋅√ℏ
# ─ + ──────────────────────────────────────────────────────────────────────────
#                                                        π⋅√m⋅√w
#
#
#
#        -m⋅w ⎞              ⎞               ⎛                       ⎛
#        ─────⎟  m⋅w         ⎟               ⎜                       ⎜         ⎛
#   3/2    ℏ  ⎟  ───         ⎟               ⎜                       ⎜4⋅√π⋅erfc⎜
# ⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝
# ────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────
#    3/2  3/2 ⎟              ⎟  ─────        ⎜           ⎝   ℏ    2⎠ ⎜       3
# 3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ          ⎜                       ⎝
# ────────────────── + ──────⎟⋅ℯ        3⋅√ℏ⋅⎜──────────────────────────────────
#                      4⋅m⋅w ⎠               ⎝
# ─────────────────────────────────── - ────────────────────────────────────────
#
#
#
#                                                                    ⎛
#                -m⋅w            -m⋅w ⎞              ⎞               ⎜
# √m⋅√w⎞         ─────           ─────⎟  m⋅w         ⎟               ⎜
# ─────⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟               ⎜
#   √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜  15⋅√π⋅√m
# ────── - ─────────── + ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜
#            3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────        ⎜
#                         3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ     5⋅√ℏ⋅⎜- ────────
# ────────────────────────────────────────── + ──────⎟⋅ℯ             ⎜
#   4⋅√ℏ                                       4⋅m⋅w ⎠               ⎝
# ─────────────────────────────────────────────────────────── - ────────────────
#       π⋅√m⋅√w
#
#
#                          ⎛                                   -m⋅w            -
#                          ⎜       ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─
#     ⎛ 2  2             ⎞ ⎜  8⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2
#     ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜       ⎝      ⎝  √ℏ ⎠    ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ
# ⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────────────── - ─────────── + ─────────
#     ⎜   2      ℏ     4 ⎟ ⎜             15                15⋅√m⋅√w         3/2
#     ⎝  ℏ               ⎠ ⎝                                            15⋅m   ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                               8⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                         π⋅√m⋅√w
#
#
# m⋅w            -m⋅w ⎞                             ⎞               ⎛
# ────           ─────⎟  m⋅w                        ⎟               ⎜
#  ℏ        5/2    ℏ  ⎟  ───                        ⎟               ⎜
#        2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟               ⎜
# ──── - ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w         ⎜15⋅√π⋅√m⋅√w
#  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────        ⎜
# w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ          ⎜
# ────────────────────────── + ─────────────────────⎟⋅ℯ        5⋅√ℏ⋅⎜───────────
#                                       2  2        ⎟               ⎜
#                                      m ⋅w         ⎠               ⎝
# ────────────────────────────────────────────────────────── + ─────────────────
#
#
#
#                       ⎛                           -m⋅w            -m⋅w
#                       ⎜           ⎛√m⋅√w⎞         ─────           ─────
#  ⎛ 2  2             ⎞ ⎜  8⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ        5
#  ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜           ⎝  √ℏ ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ
# ⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────── + ─────────── - ───────────── + ────
#  ⎜   2      ℏ     4 ⎟ ⎜         15            15⋅√m⋅√w         3/2  3/2
#  ⎝  ℏ               ⎠ ⎝                                    15⋅m   ⋅w       5⋅m
# ──────────────────────────────────────────────────────────────────────────────
#                                        8⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                   π⋅√m⋅√w
#
#
#     -m⋅w ⎞                             ⎞
#     ─────⎟  m⋅w                        ⎟                         ⎛
# /2    ℏ  ⎟  ───                        ⎟                         ⎜
#   ⋅ℯ     ⎟   ℏ                         ⎟                         ⎜
# ─────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w                   ⎜
# 5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ─────                  ⎜  3⋅√π⋅√m⋅√w
#    ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ                    ⎜
# ─────────────── + ─────────────────────⎟⋅ℯ              3/2  3/2 ⎜
#                            2  2        ⎟           122⋅m   ⋅w   ⋅⎜- ──────────
#                           m ⋅w         ⎠                         ⎝
# ───────────────────────────────────────────────, - ───────────────────────────
#
#
#
#
#              ⎛                                 -m⋅w            -m⋅w ⎞
#              ⎜     ⎛      ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟  m⋅w
#              ⎜4⋅√π⋅⎜- erfc⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟  ───
#  ⎛  m⋅w   3⎞ ⎜     ⎝      ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ
# ⋅⎜- ─── - ─⎟⋅⎜──────────────────────── + ─────────── - ─────────────⎟⋅ℯ
#  ⎝   ℏ    2⎠ ⎜           3                 3⋅√m⋅√w         3/2  3/2 ⎟
#              ⎝                                          3⋅m   ⋅w    ⎠        3
# ────────────────────────────────────────────────────────────────────────── + ─
#                               4⋅√ℏ                                           4
# ──────────────────────────────────────────────────────────────────────────────
#                                3/2
#                             3⋅ℏ   ⋅π
#
#
#      ⎞                        ⎛                       ⎛
#      ⎟                        ⎜                       ⎜         ⎛√m⋅√w⎞
#      ⎟                        ⎜                       ⎜4⋅√π⋅erfc⎜─────⎟
#      ⎟                        ⎜           ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ ⎠   4⋅√ℏ
#      ⎟  -m⋅w                  ⎜3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────── - ────
#      ⎟  ─────                 ⎜           ⎝   ℏ    2⎠ ⎜       3             3⋅
# ⋅ℏ⋅√π⎟    ℏ          3/2  3/2 ⎜                       ⎝
# ─────⎟⋅ℯ        122⋅m   ⋅w   ⋅⎜───────────────────────────────────────────────
# ...
# ──────────────────────────────────────────────────────────────────── - ───────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                    3⋅π⋅m⋅w
#
#
#                                              ⎞              ⎛       ⎛
#                                              ⎟              ⎜       ⎜
#  ⎛       3  3         2  2                  ⎞⎟              ⎜       ⎜16⋅√π⋅erf
#  ⎜  105⋅m ⋅w    1995⋅m ⋅w    5985⋅m⋅w   1575⎟⎟              ⎜       ⎜
# ⋅⎜- ───────── - ────────── - ──────── - ────⎟⎟  -m⋅w        ⎜105⋅√π⋅⎜─────────
#  ⎜        3           2        64⋅ℏ     128 ⎟⎟  ─────       ⎜       ⎜       10
#  ⎝    16⋅ℏ        32⋅ℏ                      ⎠⎟    ℏ         ⎜       ⎝
# ─────────────────────────────────────────────⎟⋅ℯ        2⋅ℏ⋅⎜─────────────────
#                7/2  7/2                      ⎟              ⎜
#               m   ⋅w                         ⎠              ⎝
# ───────────────────────────────────────────────────── + ──────────────────────
#
#
#
#                   -m⋅w            -m⋅w            -m⋅w            -m⋅w ⎞
#  ⎛√m⋅√w⎞          ─────           ─────           ─────           ─────⎟
# c⎜─────⎟            ℏ        3/2    ℏ        5/2    ℏ        7/2    ℏ  ⎟ ⎛ 4
#  ⎝  √ℏ ⎠   16⋅√ℏ⋅ℯ        8⋅ℏ   ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟ ⎜m ⋅w
# ──────── - ──────────── + ───────────── - ───────────── + ─────────────⎟⋅⎜────
# 5           105⋅√m⋅√w          3/2  3/2        5/2  5/2       7/2  7/2 ⎟ ⎜   4
#                           105⋅m   ⋅w       35⋅m   ⋅w       7⋅m   ⋅w    ⎠ ⎝  ℏ
# ──────────────────────────────────────────────────────────────────────────────
#                                                      16
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                            m⋅w
# 4       3  3        2  2                ⎞  ───           ⎛       3  3
#     14⋅m ⋅w    105⋅m ⋅w    105⋅m⋅w   105⎟   ℏ     7/2    ⎜  105⋅m ⋅w    1995⋅m
# ─ + ──────── + ───────── + ─────── + ───⎟⋅ℯ      ℏ   ⋅√π⋅⎜- ───────── - ──────
#         3            2       2⋅ℏ      16⎟                ⎜        3
#        ℏ          2⋅ℏ                   ⎠                ⎝    16⋅ℏ        32⋅ℏ
# ────────────────────────────────────────────── + ─────────────────────────────
#                                                                        7/2  7/
#                                                                       m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#  3⋅π⋅m⋅w
#
#
#                        ⎞
#                        ⎟               ⎛                         ⎛
# 2  2                  ⎞⎟               ⎜                         ⎜     ⎛
#  ⋅w    5985⋅m⋅w   1575⎟⎟               ⎜                         ⎜4⋅√π⋅⎜- erfc
# ──── - ──────── - ────⎟⎟  -m⋅w         ⎜             ⎛  m⋅w   3⎞ ⎜     ⎝
# 2        64⋅ℏ     128 ⎟⎟  ─────        ⎜  3⋅√π⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜────────────
#                       ⎠⎟    ℏ          ⎜             ⎝   ℏ    2⎠ ⎜           3
# ───────────────────────⎟⋅ℯ             ⎜                         ⎝
# 2                      ⎟          9⋅√ℏ⋅⎜- ────────────────────────────────────
#                        ⎠               ⎝
# ─────────────────────────────── - ────────────────────────────────────────────
#
#
#
#
#                      -m⋅w            -m⋅w ⎞              ⎞               ⎛
# ⎛√m⋅√w⎞    ⎞         ─────           ─────⎟  m⋅w         ⎟               ⎜
# ⎜─────⎟ + 2⎟           ℏ        3/2    ℏ  ⎟  ───         ⎟               ⎜
# ⎝  √ℏ ⎠    ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ          ⎟               ⎜
# ──────────── + ─────────── - ─────────────⎟⋅ℯ            ⎟  -m⋅w         ⎜3⋅√π
#                  3⋅√m⋅√w         3/2  3/2 ⎟              ⎟  ─────        ⎜
#                               3⋅m   ⋅w    ⎠        3⋅ℏ⋅√π⎟    ℏ          ⎜
# ──────────────────────────────────────────────── + ──────⎟⋅ℯ        9⋅√ℏ⋅⎜────
#     4⋅√ℏ                                           4⋅m⋅w ⎠               ⎝
# ───────────────────────────────────────────────────────────────── + ──────────
#       2⋅π⋅√m⋅√w
#
#
#
#                    ⎛                         -m⋅w            -m⋅w ⎞
#                    ⎜         ⎛√m⋅√w⎞         ─────           ─────⎟  m⋅w
#                    ⎜4⋅√π⋅erfc⎜─────⎟           ℏ        3/2    ℏ  ⎟  ───
#        ⎛  m⋅w   3⎞ ⎜         ⎝  √ℏ ⎠   4⋅√ℏ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ
# ⋅√m⋅√w⋅⎜- ─── - ─⎟⋅⎜──────────────── - ─────────── + ─────────────⎟⋅ℯ
#        ⎝   ℏ    2⎠ ⎜       3             3⋅√m⋅√w         3/2  3/2 ⎟
#                    ⎝                                  3⋅m   ⋅w    ⎠        3⋅ℏ
# ──────────────────────────────────────────────────────────────────────── + ───
#                                 4⋅√ℏ                                       4⋅m
# ──────────────────────────────────────────────────────────────────────────────
#                                    2⋅π⋅√m⋅√w
#
#
#                     ⎛                                   ⎛
#    ⎞                ⎜                                   ⎜       ⎛      ⎛√m⋅√w⎞
#    ⎟                ⎜              ⎛ 2  2             ⎞ ⎜  8⋅√π⋅⎜- erfc⎜─────⎟
#    ⎟                ⎜              ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜       ⎝      ⎝  √ℏ ⎠
#    ⎟                ⎜  15⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ───────────────────
#    ⎟  -m⋅w          ⎜              ⎜   2      ℏ     4 ⎟ ⎜             15
#    ⎟  ─────         ⎜              ⎝  ℏ               ⎠ ⎝
# ⋅√π⎟    ℏ     10⋅√ℏ⋅⎜- ───────────────────────────────────────────────────────
# ───⎟⋅ℯ              ⎜                                                        8
# ⋅w ⎠                ⎝
# ─────────── + ────────────────────────────────────────────────────────────────
#
#
#
#               -m⋅w            -m⋅w            -m⋅w ⎞
#     ⎞         ─────           ─────           ─────⎟  m⋅w
#  + 2⎟           ℏ        3/2    ℏ        5/2    ℏ  ⎟  ───
#     ⎠   8⋅√ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ
# ───── - ─────────── + ───────────── - ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w
#           15⋅√m⋅√w         3/2  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── -
#                        15⋅m   ⋅w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ
# ───────────────────────────────────────────────────────── + ──────────────────
# ⋅√ℏ                                                                  2  2
#                                                                     m ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#          π⋅√m⋅√w
#
#
#    ⎞                ⎛                                 ⎛
#    ⎟                ⎜                                 ⎜           ⎛√m⋅√w⎞
#    ⎟                ⎜            ⎛ 2  2             ⎞ ⎜  8⋅√π⋅erfc⎜─────⎟
#    ⎟                ⎜            ⎜m ⋅w    5⋅m⋅w   15⎟ ⎜           ⎝  √ℏ ⎠   8⋅
# 45⎞⎟  -m⋅w          ⎜15⋅√π⋅√m⋅√w⋅⎜───── + ───── + ──⎟⋅⎜- ──────────────── + ──
# ──⎟⎟  ─────         ⎜            ⎜   2      ℏ     4 ⎟ ⎜         15
# 16⎠⎟    ℏ           ⎜            ⎝  ℏ               ⎠ ⎝
# ───⎟⋅ℯ        10⋅√ℏ⋅⎜─────────────────────────────────────────────────────────
#    ⎟                ⎜                                                  8⋅√ℏ
#    ⎠                ⎝
# ─────────── - ────────────────────────────────────────────────────────────────
#
#
#
#     -m⋅w            -m⋅w            -m⋅w ⎞                             ⎞
#     ─────           ─────           ─────⎟  m⋅w                        ⎟
#       ℏ        3/2    ℏ        5/2    ℏ  ⎟  ───                        ⎟
# √ℏ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ                         ⎟
# ───────── - ───────────── + ─────────────⎟⋅ℯ       2    ⎛  15⋅m⋅w   45⎞⎟  -m⋅w
# 15⋅√m⋅√w         3/2  3/2       5/2  5/2 ⎟        ℏ ⋅√π⋅⎜- ────── - ──⎟⎟  ────
#              15⋅m   ⋅w       5⋅m   ⋅w    ⎠              ⎝   8⋅ℏ     16⎠⎟    ℏ
# ─────────────────────────────────────────────── + ─────────────────────⎟⋅ℯ
#                                                            2  2        ⎟
#                                                           m ⋅w         ⎠
# ──────────────────────────────────────────────────────────────────────────────
#     π⋅√m⋅√w
#
#
#           ⎛                                                    ⎛
#           ⎜                                                    ⎜      ⎛      ⎛
#           ⎜               ⎛   3  3       2  2                ⎞ ⎜16⋅√π⋅⎜- erfc⎜
#           ⎜               ⎜  m ⋅w    21⋅m ⋅w    105⋅m⋅w   105⎟ ⎜      ⎝      ⎝
#           ⎜  105⋅√π⋅√m⋅√w⋅⎜- ───── - ──────── - ─────── - ───⎟⋅⎜──────────────
# ─         ⎜               ⎜     3         2       4⋅ℏ      8 ⎟ ⎜           105
#           ⎜               ⎝    ℏ       2⋅ℏ                   ⎠ ⎝
#     14⋅√ℏ⋅⎜- ─────────────────────────────────────────────────────────────────
#           ⎜
#           ⎝
# ─ - ──────────────────────────────────────────────────────────────────────────
#
#
#
#                      -m⋅w            -m⋅w            -m⋅w            -m⋅w ⎞
# √m⋅√w⎞    ⎞          ─────           ─────           ─────           ─────⎟  m
# ─────⎟ + 2⎟            ℏ        3/2    ℏ        5/2    ℏ        7/2    ℏ  ⎟  ─
#   √ℏ ⎠    ⎠   16⋅√ℏ⋅ℯ        8⋅ℏ   ⋅ℯ        4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟
# ─────────── + ──────────── - ───────────── + ───────────── - ─────────────⎟⋅ℯ
#                105⋅√m⋅√w          3/2  3/2        5/2  5/2       7/2  7/2 ⎟
#                              105⋅m   ⋅w       35⋅m   ⋅w       7⋅m   ⋅w    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#      16⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                      3⋅π⋅√m⋅√w
#
#
#                                        ⎞                ⎛
# ⋅w                                     ⎟                ⎜
# ──         ⎛     2  2                 ⎞⎟                ⎜             ⎛   3  3
# ℏ     3    ⎜105⋅m ⋅w    315⋅m⋅w   1575⎟⎟                ⎜             ⎜  m ⋅w
#      ℏ ⋅√π⋅⎜───────── + ─────── + ────⎟⎟  -m⋅w          ⎜105⋅√π⋅√m⋅√w⋅⎜- ─────
#            ⎜      2       8⋅ℏ      64 ⎟⎟  ─────         ⎜             ⎜     3
#            ⎝  16⋅ℏ                    ⎠⎟    ℏ           ⎜             ⎝    ℏ
# ── + ──────────────────────────────────⎟⋅ℯ        14⋅√ℏ⋅⎜─────────────────────
#                     3  3               ⎟                ⎜
#                    m ⋅w                ⎠                ⎝
# ─────────────────────────────────────────────── + ────────────────────────────
#
#
#
#                              ⎛                           -m⋅w            -m⋅w
#                              ⎜          ⎛√m⋅√w⎞          ─────           ─────
#        2  2                ⎞ ⎜16⋅√π⋅erfc⎜─────⎟            ℏ        3/2    ℏ
#    21⋅m ⋅w    105⋅m⋅w   105⎟ ⎜          ⎝  √ℏ ⎠   16⋅√ℏ⋅ℯ        8⋅ℏ   ⋅ℯ
#  - ──────── - ─────── - ───⎟⋅⎜───────────────── - ──────────── + ─────────────
#         2       4⋅ℏ      8 ⎟ ⎜       105           105⋅√m⋅√w          3/2  3/2
#      2⋅ℏ                   ⎠ ⎝                                   105⋅m   ⋅w
# ──────────────────────────────────────────────────────────────────────────────
#                                              16⋅√ℏ
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                               3⋅π⋅√m⋅√w
#
#
#            -m⋅w            -m⋅w ⎞                                          ⎞
#            ─────           ─────⎟  m⋅w                                     ⎟
#       5/2    ℏ        7/2    ℏ  ⎟  ───         ⎛     2  2                 ⎞⎟
#    4⋅ℏ   ⋅ℯ        2⋅ℏ   ⋅ℯ     ⎟   ℏ     3    ⎜105⋅m ⋅w    315⋅m⋅w   1575⎟⎟
#  - ───────────── + ─────────────⎟⋅ℯ      ℏ ⋅√π⋅⎜───────── + ─────── + ────⎟⎟
#         5/2  5/2       7/2  7/2 ⎟              ⎜      2       8⋅ℏ      64 ⎟⎟
#     35⋅m   ⋅w       7⋅m   ⋅w    ⎠              ⎝  16⋅ℏ                    ⎠⎟
# ────────────────────────────────────── + ──────────────────────────────────⎟⋅ℯ
#                                                         3  3               ⎟
#                                                        m ⋅w                ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ⎤
#      ⎥
#      ⎥
#      ⎥
# -m⋅w ⎥
# ─────⎥
#   ℏ  ⎥
#      ⎥
#      ⎥
#      ⎥
# ─────⎥
#      ⎥
#      ⎦

# %% [markdown]
# Ahora vamos con la función de onda $(\psi)$

# %%
form_item_layout = Layout(
    display='flex',
    flex_flow='row',
    justify_content='space-between')

Graph=IntSlider(min=n_inf, max=n_sup, step=1, disabled=False, continuous_update=False, orientation='horizontal',\
                readout=True, readout_format='d')

form_items = [
    Box([Label(value='What function do you want to see?'),
         Graph], layout=form_item_layout)]

form = Box(form_items, layout=Layout(
    display='flex',
    flex_flow='column',
    border='solid 2px',
    align_items='stretch',
    width='40%'))
form

# %% [markdown]
# La función de onda original es:

# %%
Psin.subs({n:Graph.value})
# Out:
#                       2
#                 -m⋅w⋅x
#                 ────────
#     3/4  3/4      2⋅ℏ
# √2⋅m   ⋅w   ⋅x⋅ℯ
# ────────────────────────
#         3/4 4 ___
#        ℏ   ⋅╲╱ π

# %% [markdown]
# La correción a primer orden a la función de onda (utilizando todas las funciones en el rango seleccionado) es:

# %%
Psi_c[Graph.value-n_inf]
# Out:
#
#
#                       2                                  ⎛   3/2  3/2  3
#                 -m⋅w⋅x                             4 ___ ⎜8⋅m   ⋅w   ⋅x    12⋅
#                 ────────   4.83902992837821e+32⋅√3⋅╲╱ m ⋅⎜────────────── - ───
#     3/4  3/4      2⋅ℏ                                    ⎜      3/2
# √2⋅m   ⋅w   ⋅x⋅ℯ                                         ⎝     ℏ
# ──────────────────────── - ───────────────────────────────────────────────────
#         3/4 4 ___                                     4 ___ 4 ___  3/4
#        ℏ   ⋅╲╱ π                                      ╲╱ ℏ ⋅╲╱ π ⋅w
#
#                 2
#           -m⋅w⋅x                                                         2
#        ⎞  ────────                                                 -m⋅w⋅x
# √m⋅√w⋅x⎟    2⋅ℏ                                    ⎛       2    ⎞  ────────
# ───────⎟⋅ℯ                                   4 ___ ⎜4⋅m⋅w⋅x     ⎟    2⋅ℏ
#  √ℏ    ⎟             2.37063083491664e+33⋅√2⋅╲╱ m ⋅⎜──────── - 2⎟⋅ℯ
#        ⎠                                           ⎝   ℏ        ⎠
# ────────────────── + ────────────────────────────────────────────────────── -
#                                         4 ___ 4 ___  3/4
#                                         ╲╱ ℏ ⋅╲╱ π ⋅w
#
#
#
#                                   2
#                             -m⋅w⋅x
#                             ────────
#                      4 ___    2⋅ℏ
# 6.70515655623796e+33⋅╲╱ m ⋅ℯ
# ────────────────────────────────────
#           4 ___ 4 ___  3/4
#           ╲╱ ℏ ⋅╲╱ π ⋅w

# %% [markdown]
# Vamos a graficarlas para verlas mejor...

# %% [markdown]
# La función de onda original es:

# %%
if Problem=='Particle in a one-dimensional box':
    plot(eval(str(Psin)).subs({n:Graph.value,m:mass,l:large,w:omega,hbar:h}),xlim=(li_scipy,ls_scipy),\
         title='$\psi_{%d}$'%Graph.value)
if Problem=='Harmonic oscilator':
    plot(eval(str(Psin)).subs({n:Graph.value,m:mass,l:large,w:omega,hbar:h}),xlim=(-10*h/(mass*omega),10*h/(mass*omega)),\
         title='$\psi_{%d}$'%Graph.value)
if Problem=='Hydrogen atom (Helium correction)':
    print('Densidad de probabilidad para un electrón')
    plot(eval(str((4*pi*x**2*R_nl(Graph.value,q,x,z)**2))),xlim=(0,10),ylim=(0,20/Graph.value), title='$\psi_{%ds}$'%Graph.value)
    print('Tome en cuenta que debido a la dificultad para seleccionar los límites de la gráfica se muestran bien los primeros\n\
3 estados. A partir de ahí visualizar la gráfica se complica.')

# %% [markdown]
# La corrección a la función de onda es:

# %%
if Problem=='Particle in a one-dimensional box':
    if Pert.value!='':
        plot(eval(str(Psi_c[Graph.value-n_inf])).subs({n:Graph.value,m:mass,l:large,w:omega,hbar:h}),\
             xlim=(li_scipy,ls_scipy),title='$\psi_{%d}$'%Graph.value)
    if Pert.value=='':
        print('No se ingreso ninguna perturbación')
if Problem=='Harmonic oscilator':
    if Pert.value!='':
        plot(eval(str(Psi_c[Graph.value-n_inf])).subs({n:Graph.value,m:mass,l:large,w:omega,hbar:h}),\
             xlim=(-10*h/(mass*omega),10*h/(mass*omega)),title='$\psi_{%d}$' %Graph.value)
    if Pert.value=='':
        print('No se ingreso ninguna perturbación')
if Problem=='Hydrogen atom (Helium correction)':
    print('Este programa no corrige las fucniones de un átomo hidrogenoide')

# %% [markdown]
# **Tarea 4.  Resolver el átomo de helio aplicando los programas anteriores.**

# %% [markdown]
# Para resolver el átomo de helio se utilizaron los conceptos, que sirvieron como base para las primeras tareas. Sin embargo, en el Apéndice 1 viene con mayor detalles las consideraciones tomadas para resolver el problema.

# %% [markdown]
# ## Apéndice 1

# %% [markdown]
# Para el cálculo a las correciones del átomo de Helio se tomó en cuenta lo siguiente...

# %% [markdown]
# La función de onda del átomo de Helio puede ser representada como:
#
# $$ \psi_{nlm} = \psi(r1)_{nlm} \psi(r2)_{nlm}$$

# %% [markdown]
# Donde, para el estado fundamental:
#
# $$ \psi(r_{1}.r_{2})_{100} = \frac{Z^{3}}{\pi a_{0}^{3}} e^{\frac{-Z}{a_{0}}(r_{1}+r_{2})}$$

# %% [markdown]
# Y la perturbación sería el término de repulsión entre los dos electrones, es decir:
#
# $$ H'= \frac{e^{2}}{r_{12}}=\frac{e^{2}}{|r_{1}-r_{2}|}$$

# %% [markdown]
# Finalmente la correción a primer orden de la energía sería:
#
# $$ E^{1}= \langle\psi_{n}^{(0)} | H' | \psi_{n}^{(0)} \rangle =\frac{Z^{6}e^{2}}{\pi^{2} a_{0}^{6}} \int_{0}^{2\pi}\int_{0}^{2\pi}\int_{0}^{\pi}\int_{0}^{\pi}\int_{0}^{\infty}\int_{0}^{\infty} \frac{e^{\frac{-2Z}{a_{0}}(r_{1}+r_{2})}}{r_{12}} r_{1}^{2}r_{2}^{2}sen{\theta_{1}}sen{\theta_{2}} dr_{2} dr_{1} d\theta_{2} d\theta_{1} d\phi_{2} d\phi_{1}$$

# %% [markdown]
# Se utiliza una expansión del termino de repulsión con los armónicos esféricos y se integra la parte angular. Una vez hecho eso, la integral queda expresada de la siguiente manera:

# %% [markdown]
# $$ E^{1}= \frac{16Z^{6}e^{2}}{a_{0}^{6}} \left[\int_{0}^{\infty} r_{1}^{2} e^{\frac{-2Z}{a_{0}}r_{1}} \left(\int_{0}^{r_{1}} \frac{r_{2}^{2}}{r_{1}} e^{\frac{-2Z}{a_{0}}r_{2}} dr_{2}+\int_{r_{1}}^{\infty}r_{2} e^{\frac{-2Z}{a_{0}}r_{2}}dr_{2}\right) dr_{1} \right]$$

# %% [markdown]
# **Tarea 5: Método variacional-perturbativo. **

# %% [markdown]
# Este método nos permite estimar de forma precisa $E^{(2)}$ y correcciones perturbativas de la energía de órdenes más elevados para el estado fundamental del sistema, sin evaluar sumas infinitas. Ver ecuación 9.38 del libro.

# %% [markdown]
# **Tarea 6. Revisar sección 9.7. **
#
# Inicialmente a mano, y sengunda instancia favor de intentar programar sección del problema, i.e. integral de Coulomb  e integral de intercambio.
